# %%
# %matplotlib auto
import numpy as np
import cv2
from keras.preprocessing.image import ImageDataGenerator

from skimage import io
import os
from skimage.filters import threshold_yen
from skimage.exposure import rescale_intensity
from skimage.io import imread, imsave
from matplotlib import pyplot as plt 

from PIL import Image
import imutils
# Out:
# Using matplotlib backend: Qt5Agg

# %%
input = r"C:\Users\Oliver\Documents\Projects\Resistor-Color-Code-Scanner\Resistor-color-code-scanner\test_resistors\test_resistor7.jpg"
img_rgb_rectangle = cv2.imread(input)
img_rgb = cv2.imread(input)

#img_rgb = cv2.resize(img_rgb, (1600,1600), interpolation = cv2.INTER_LINEAR_EXACT)
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY) 
template = cv2.imread(r"C:\Users\Oliver\Documents\Projects\Resistor-Color-Code-Scanner\Resistor-color-code-scanner\test_resistors\test_resistor7_crop.jpg",0) 
w, h = template.shape[::-1] 
res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED) 
threshold = 0.8 
loc = np.where(res >= threshold)

for pt in zip(*loc[::-1]): #Draw rectangle around ROI
    cv2.rectangle(img_rgb_rectangle, pt, (pt[0] + w, pt[1] + h), (255,255,255), 1)
    
    
file = 'resistor_found.jpg'
cv2.imwrite(file, img_rgb_rectangle)

print(pt[0], pt[1])
    
print(pt[0] + w, pt[1] + h)

roi = img_rgb[pt[1]:pt[1]+h, pt[0]:pt[0]+w]
cv2.imwrite("roi.jpg", roi)
# Out:
# 249 254
# 646 392
# True

# %%
#cap = cv2.VideoCapture(0);
#cap.set(cv2.CAP_PROP_AUTOFOCUS, 1)

#cap.set(3,1280) 
#cap.set(4,720)

colors = {}

while True:

    frame = cv2.imread('roi.jpg')
    
    height, width, channels = frame.shape
    #_, frame = cap.read()
    #frame = cv2.resize(frame, (height*4,width*4), interpolation = cv2.INTER_LINEAR_EXACT)
    
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)


    lower_blue = np.array([100,150,0]) #lower boundry
    upper_blue = np.array([120, 255, 255]) #upper boundry
    
    lower_green = np.array([59, 28, 46]) #lower boundry, original 40,70,80
    upper_green = np.array([104, 255, 168]) #upper boundry, original 70, 255, 255
    
    lower_red = np.array([175, 81, 79]) 
    upper_red = np.array([179, 255, 255]) 
    
    lower_yellow = np.array([21, 89, 138]) #lower boundry
    upper_yellow = np.array([123, 255, 255]) #upper boundry
    
    lower_orange = np.array([5, 190, 200]) #5, 190, 200
    upper_orange = np.array([18, 225, 255]) #18, 225, 255
    
    lower_violet = np.array([[92, 74, 89]])
    upper_violet = np.array([174, 255, 255])
    
    lower_black = np.array([[0, 0, 0]])
    upper_black = np.array([41, 150, 61])
    
    lower_brown = np.array([[7, 181, 85]])
    upper_brown = np.array([13, 255, 182])
    
    lower_brown_light = np.array([[4, 109, 138]])
    upper_brown_light = np.array([11, 255, 233])
    
    lower_black_light = np.array([[0, 0, 0]])
    upper_black_light = np.array([179, 255, 14])
    
    lower_violet_dark = np.array([[92, 74, 0]])
    upper_violet_dark = np.array([174, 255, 255])
    
    lower_red_dark = np.array([28, 78, 136]) 
    upper_red_dark = np.array([179, 255, 255]) 
    
    

    mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)
    mask_red = cv2.inRange(hsv, lower_red, upper_red)
    mask_yellow = cv2.inRange(hsv, lower_yellow, upper_yellow)
    mask_orange = cv2.inRange(hsv, lower_orange, upper_orange)
    mask_violet = cv2.inRange(hsv, lower_violet, upper_violet)
    mask_black = cv2.inRange(hsv, lower_black, upper_black)
    mask_brown = cv2.inRange(hsv, lower_brown, upper_brown)
    mask_brown_light = cv2.inRange(hsv, lower_brown_light, upper_brown_light)
    mask_black_light = cv2.inRange(hsv, lower_black_light, upper_black_light)
    mask_violet_dark = cv2.inRange(hsv, lower_violet_dark, upper_violet_dark)
    mask_red_dark = cv2.inRange(hsv, lower_red_dark, upper_red_dark)
    
    contour1 = cv2.findContours(mask_blue, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour1 = imutils.grab_contours(contour1)
    
    contour2 = cv2.findContours(mask_green, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour2 = imutils.grab_contours(contour2)
    
    contour3 = cv2.findContours(mask_red, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour3 = imutils.grab_contours(contour3)
    
    contour4 = cv2.findContours(mask_yellow, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour4 = imutils.grab_contours(contour4)
    
    contour5 = cv2.findContours(mask_orange, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour5 = imutils.grab_contours(contour5)
    
    contour6 = cv2.findContours(mask_violet, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour6 = imutils.grab_contours(contour6)
    
    contour7 = cv2.findContours(mask_black, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour7 = imutils.grab_contours(contour7)
    
    contour8 = cv2.findContours(mask_brown, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour8 = imutils.grab_contours(contour8)
    
    contour9 = cv2.findContours(mask_brown_light, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour9 = imutils.grab_contours(contour9)
    
    contour10 = cv2.findContours(mask_black_light, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour10 = imutils.grab_contours(contour10)
    
    contour11 = cv2.findContours(mask_violet_dark, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour11 = imutils.grab_contours(contour11)
    
    contour12 = cv2.findContours(mask_red_dark, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour12 = imutils.grab_contours(contour12)
    
    area_limit = 600
    for c in contour1:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("blue", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            x1,y1,w1,h1 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x1,y1),(x1+w1,y1+h1),(255,255,0),1)
            cv2.putText(frame, "Blue", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
            
            if x1 not in colors:
                colors[x1] = 'Blue'
                
            
    for c in contour2:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("green", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            # Find bounding rectangles
            x2,y2,w2,h2 = cv2.boundingRect(c)
            # Draw the rectangle
            cv2.rectangle(frame,(x2,y2),(x2+w2,y2+h2),(255,255,0),1)
            cv2.putText(frame, "Green", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)
            
            if x2 not in colors:
                colors[x2] = 'Green'
    
    for c in contour3:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("red", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            x3,y3,w3,h3 = cv2.boundingRect(c)
            
            cv2.rectangle(frame,(x3,y3),(x3+w3,y3+h3),(255,255,0),1)
            
            cv2.putText(frame, "Red", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
            
            if x3 not in colors:
                colors[x3] = 'Red'
    
    for c in contour4:
        
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("yellow", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            x4,y4,w4,h4 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x4,y4),(x4+w4,y4+h4),(255,255,0),1)
            
            cv2.putText(frame, "Yellow", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 3)
            
            if x4 not in colors:
                colors[x4] = 'Yellow'

    for c in contour5:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("orange", area)
            
            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x5,y5,w5,h5 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x5,y5),(x5+w5,y5+h5),(255,255,0),1)
            cv2.putText(frame, "Orange", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (2, 106, 255), 3)
            
            if x5 not in colors:
                colors[x5] = 'Orange'

    
    for c in contour6:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("violet", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x6,y6,w6,h6 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x6,y6),(x6+w6,y6+h6),(255,255,0),1)
            cv2.putText(frame, "Violet", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (238, 130, 238), 3)
            
            if x6 not in colors:
                colors[x6] = 'Violet'


    for c in contour7:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("black", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x7,y7,w7,h7 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x7,y7),(x7+w7,y7+h7),(255,255,0),1)
            cv2.putText(frame, "Black", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (50, 0, 0), 3)
            
            if x7 not in colors:
                colors[x7] = 'Black'

    
    for c in contour8:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("brown", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x8,y8,w8,h8 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x8,y8),(x8+w8,y8+h8),(255,255,0),1)
            cv2.putText(frame, "Brown", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (42, 42, 165), 3)
            
            if x8 not in colors:
                colors[x8] = 'Brown'

    
    for c in contour9:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("brown light", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x9,y9,w9,h9 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x9,y9),(x9+w9,y9+h9),(255,255,0),1)
            cv2.putText(frame, "Brown", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (42, 42, 165), 3)
            
            if x9 not in colors:
                colors[x9] = 'Brown'

    
    for c in contour10:
        area = cv2.contourArea(c)
        #print("black", area)
        if area > area_limit:
            
            #print("black light", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x10,y10,w10,h10 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x10,y10),(x10+w10,y10+h10),(255,255,0),1)
            cv2.putText(frame, "Black", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 50), 3)
            
            if x10 not in colors:
                colors[x10] = 'Black'

    for c in contour11:
        area = cv2.contourArea(c)
        #if area > 500:
            #print(area)
        if area > area_limit:
            
            #print("violet dark", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x11,y11,w11,h11 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x11,y11),(x11+w11,y11+h11),(255,255,0),1)
            cv2.putText(frame, "Violet", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (238, 130, 238), 3)
            
            if x11 not in colors:
                colors[x11] = 'Violet'
                
    for c in contour12:
        area = cv2.contourArea(c)
        #print("red dark", area)
        if area > area_limit:
            #print("red dark", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            x12,y12,w12,h12 = cv2.boundingRect(c)
            
            cv2.rectangle(frame,(x12,y12),(x12+w12,y12+h12),(255,255,0),1)
            
            cv2.putText(frame, "Red", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
            
            if x12 not in colors:
                colors[x12] = 'Red'
        
    #Display ohm
    color_bands = {"Black": 0, "Brown": 1, "Red": 2, "Orange": 3, "Yellow": 4, "Green": 5, "Blue": 6, "Violet": 7, "Grey": 8, "White": 9}
    color_multipliers = {"Black": 1, "Brown": 10, "Red": 100, "Orange": 1000, "Yellow": 10000, "Green": 100000, "Blue":1000000 , "Violet": 10000000, "Grey": 100000000, "White": 100000000}

    colors_list = []
    for color in colors.keys():
             colors_list.append(color)

    colors_list = sorted(colors_list)

    if len(colors_list) < 3:
        color1 = colors[colors_list[0]]
        color2 = colors[colors_list[1]]
    else:
        color1 = colors[colors_list[0]]
        color2 = colors[colors_list[1]]
        color3 = colors[colors_list[2]]

    combined = int(str(color_bands[color1]) + str(color_bands[color2]))

    ohms = str(combined*color_multipliers[color3])
    cv2.putText(frame,ohms + ' ohm',(0,int(height*0.9)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    
    #Close window
    key = cv2.waitKey(1) 
    if key == 27:
        break
    
    cv2.imshow("result",frame)
    
    
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# red dark 0.0
# red dark 15.5
# red dark 0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-41b425bf1638> in <module>
#     411
#     412
# --> 413 cap.release()
#     414 cv2.destroyAllWindows()
#     415 cv2.waitKey(1)
#
# NameError: name 'cap' is not defined

# %%
# Out:
# 768

# %%
# Out:
# 5
