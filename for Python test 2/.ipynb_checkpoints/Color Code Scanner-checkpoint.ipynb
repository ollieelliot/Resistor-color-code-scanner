# %%
# %matplotlib auto
import numpy as np
import cv2
from keras.preprocessing.image import ImageDataGenerator

from skimage import io
import os
from skimage.filters import threshold_yen
from skimage.exposure import rescale_intensity
from skimage.io import imread, imsave
from matplotlib import pyplot as plt 

from PIL import Image
import imutils
# Out:
# Using matplotlib backend: Qt5Agg

# %%
import requests
address = 'http://192.168.0.30:8080/shot.jpg'
colors = {}
ohms_list = []
#input = "/Users/oliver/Downloads/resistor_photo.jpeg"

color_bands = {"Black": 0, "Brown": 1, "Red": 2, "Orange": 3, "Yellow": 4, "Green": 5, "Blue": 6, "Violet": 7, "Grey": 8, "White": 9}
color_multipliers = {"Black": 1, "Brown": 10, "Red": 100, "Orange": 1000, "Yellow": 10000, "Green": 100000, "Blue":1000000 , "Violet": 10000000, "Grey": 100000000, "White": 100000000}


temp_start = (900, 545)
temp_end = (1000, 550)


while True:
        
    img_resp = requests.get(address)
    img_arr = np.array(bytearray(img_resp.content), dtype=np.uint8)
    frame = cv2.imdecode(img_arr, -1)
    #frame = cv2.imread(input)
    height, width, channels = frame.shape
    #start = (int(width/2 - 50), int(height/2))
    #end = (int(width/2 + 50),int(height/2) + 30)
    show_frame = frame
    
    cv2.bilateralFilter(frame, 5, 800, 800)
    
    cv2.rectangle(frame, temp_start, temp_end, (255,255,255), 1)
    
    frame = frame[550:560, 900:1000]
    
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)


    lower_blue = np.array([80, 50, 50]) #lower boundry
    upper_blue = np.array([106, 250, 150]) #upper boundry
    
    lower_green = np.array([40, 33, 80]) #lower boundry, original 40,70,80
    upper_green = np.array([80, 115, 255]) #upper boundry, original 70, 255, 255
    
    lower_red = np.array([0, 95, 0]) #0,5,0
    upper_red = np.array([7, 255, 190]) #7,255,189
    
    lower_yellow = np.array([19, 87, 136]) #lower boundry
    upper_yellow = np.array([24, 255, 255]) #upper boundry
    
    lower_orange = np.array([8, 103, 160]) #5, 190, 200
    upper_orange = np.array([14, 170, 255]) #18, 225, 255
    
    lower_violet = np.array([[114, 0, 0]])
    upper_violet = np.array([179, 255, 255])
    
    lower_black = np.array([[0, 0, 0]])
    upper_black = np.array([179, 255, 84])
    
    lower_brown = np.array([7, 72, 0]) #0,100,0
    upper_brown = np.array([13, 255, 145]) #12,255,121
    
    lower_brown_dark = np.array([[8, 38, 0]])
    upper_brown_dark = np.array([15, 255, 114])
    
    lower_black_light = np.array([[0, 0, 0]])
    upper_black_light = np.array([179, 255, 14])
    
    lower_violet_dark = np.array([[92, 74, 0]])
    upper_violet_dark = np.array([174, 255, 255])
    
    lower_red_dark = np.array([171, 65, 50]) 
    upper_red_dark = np.array([180, 250, 150]) 
    
    

    mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)
    mask_red = cv2.inRange(hsv, lower_red, upper_red)
    mask_yellow = cv2.inRange(hsv, lower_yellow, upper_yellow)
    mask_orange = cv2.inRange(hsv, lower_orange, upper_orange)
    mask_violet = cv2.inRange(hsv, lower_violet, upper_violet)
    mask_black = cv2.inRange(hsv, lower_black, upper_black)
    mask_brown = cv2.inRange(hsv, lower_brown, upper_brown)
    mask_brown_light = cv2.inRange(hsv, lower_brown_dark, upper_brown_dark)
    mask_black_light = cv2.inRange(hsv, lower_black_light, upper_black_light)
    mask_violet_dark = cv2.inRange(hsv, lower_violet_dark, upper_violet_dark)
    mask_red_dark = cv2.inRange(hsv, lower_red_dark, upper_red_dark)
    
    contour1 = cv2.findContours(mask_blue, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour1 = imutils.grab_contours(contour1)
    
    contour2 = cv2.findContours(mask_green, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour2 = imutils.grab_contours(contour2)
    
    contour3 = cv2.findContours(mask_red, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour3 = imutils.grab_contours(contour3)
    
    contour4 = cv2.findContours(mask_yellow, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour4 = imutils.grab_contours(contour4)
    
    contour5 = cv2.findContours(mask_orange, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour5 = imutils.grab_contours(contour5)
    
    contour6 = cv2.findContours(mask_violet, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour6 = imutils.grab_contours(contour6)
    
    contour7 = cv2.findContours(mask_black, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour7 = imutils.grab_contours(contour7)
    
    contour8 = cv2.findContours(mask_brown, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour8 = imutils.grab_contours(contour8)
    
    contour9 = cv2.findContours(mask_brown_light, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour9 = imutils.grab_contours(contour9)
    
    contour10 = cv2.findContours(mask_black_light, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour10 = imutils.grab_contours(contour10)
    
    contour11 = cv2.findContours(mask_violet_dark, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour11 = imutils.grab_contours(contour11)
    
    contour12 = cv2.findContours(mask_red_dark, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour12 = imutils.grab_contours(contour12)
    
    area_limit = 30
    brown_area_limit = 30
    
                
    for c in contour1:
        area = cv2.contourArea(c)
        if area > area_limit:
            
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x1,y1,w1,h1 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x1,y1),(x1+w1,y1+h1),(255,255,0),1)
            #cv2.putText(frame, "Blue", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
            
            if x1 not in colors:
                colors[x1] = 'Blue'
                
            
    for c in contour2:
        area = cv2.contourArea(c)
        print("green", area)
        if area > area_limit:
            print("green", area)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])
            
            x2,y2,w2,h2 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x2,y2),(x2+w2,y2+h2),(255,255,0),1)
            #cv2.putText(frame, "Green", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)
            
            if x2 not in colors:
                colors[x2] = 'Green'
    
    for c in contour3:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("red", area)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x3,y3,w3,h3 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x3,y3),(x3+w3,y3+h3),(255,255,0),1)
            #cv2.putText(frame, "Red", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
            
            if x3 not in colors:
                colors[x3] = 'Red'
    
    for c in contour4:
        
        area = cv2.contourArea(c)
        if area > area_limit:
            print("yellow", area)
            
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x4,y4,w4,h4 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x4,y4),(x4+w4,y4+h4),(255,255,0),1)
            #cv2.putText(frame, "Yellow", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 3)
            
            if x4 not in colors:
                colors[x4] = 'Yellow'

    for c in contour5:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("orange", area)
          
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])
            
            x5,y5,w5,h5 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x5,y5),(x5+w5,y5+h5),(255,255,0),1)
            #cv2.putText(frame, "Orange", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (2, 106, 255), 3)
            
            if x5 not in colors:
                colors[x5] = 'Orange'

    
    for c in contour6:
        area = cv2.contourArea(c)
        print(area, " lila")
        if area > area_limit:
        
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x6,y6,w6,h6 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x6,y6),(x6+w6,y6+h6),(255,255,0),1)
            #cv2.putText(frame, "Violet", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (238, 130, 238), 3)
            
            if x6 not in colors:
                colors[x6] = 'Violet'


    for c in contour7:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("black", area)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x7,y7,w7,h7 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x7,y7),(x7+w7,y7+h7),(255,255,0),1)
            #cv2.putText(frame, "Black", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (50, 0, 0), 3)
            
            if x7 not in colors:
                colors[x7] = 'Black'

    
    for c in contour8:
        area = cv2.contourArea(c)
        if area > brown_area_limit:
            print("brown", area)
            
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x8,y8,w8,h8 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x8,y8),(x8+w8,y8+h8),(255,255,0),1)
            #cv2.putText(frame, "Brown", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (42, 42, 165), 3)
            
            if x8 not in colors:
                colors[x8] = 'Brown'

    
    for c in contour9:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("dark brown")

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])
            
            x9,y9,w9,h9 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x9,y9),(x9+w9,y9+h9),(255,255,0),1)
            #cv2.putText(frame, "Brown", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (42, 42, 165), 3)
            
            if x9 not in colors:
                colors[x9] = 'Brown'

    
    for c in contour10:
        area = cv2.contourArea(c)
        #print("black", area)
        if area > area_limit:

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x10,y10,w10,h10 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x10,y10),(x10+w10,y10+h10),(255,255,0),1)
            #cv2.putText(frame, "Black", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 50), 3)
            
            if x10 not in colors:
                colors[x10] = 'Black'

    for c in contour11:
        area = cv2.contourArea(c)
        #if area > 500:
            #print(area)
        if area > area_limit:

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x11,y11,w11,h11 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x11,y11),(x11+w11,y11+h11),(255,255,0),1)
            #cv2.putText(frame, "Violet", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (238, 130, 238), 3)
            
            #if x11 not in colors:
                #colors[x11] = 'Violet'
                
    for c in contour12:
        area = cv2.contourArea(c)
        #print("red dark", area)
        if area > area_limit:
            print("red dark", area)
            
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])
            
            x12,y12,w12,h12 = cv2.boundingRect(c)
            #cv2.rectangle(frame,(x12,y12),(x12+w12,y12+h12),(255,255,0),1)
            #cv2.putText(frame, "Red", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
            
            #if x12 not in colors:
                #colors[x12] = 'Red'
        
    
    #Display ohm
    colors_list = []
    for color in colors.keys():
             colors_list.append(color)

    colors_list = sorted(colors_list)
    print(colors_list, " sorted and before pop")
    
    
    #If two of the same colors are almost on the same x-position, chose only one.
    #Remove colors that are near the same X-coordinate (e.g. if there are two 
    #colors detected on the same stripe)
    for i in range(len(colors_list)):
        try:
            if len(colors_list) > 3 and colors_list[i] - (colors_list[i+1]) < 0:
                print("reached if pop")
                test = colors_list.pop(i+1)
                print("popped: ", test)
               
        except IndexError:
            print("index error")

            
    print(colors_list, " sorted and after pop")
    
    
    
    if len(colors_list) <3:
        print("reached if")
        color1 = "Black" # 0 ohm if less than 3 colors detected 
        color2 = "Black"
        color3 = "Black"
                
    else:
        color1 = colors[colors_list[0]]
        color2 = colors[colors_list[1]]
        color3 = colors[colors_list[2]]
        print("Colors: ", color1, color2, " * ", color3)
        colors = {}
        

    combined = int(str(color_bands[color1]) + str(color_bands[color2]))

    ohms = combined*color_multipliers[color3]
    
    if ohms < 10**3:
        ohms = (combined*color_multipliers[color3])
        disp = str(ohms)
    if ohms < 10**6 and ohms > 10**3:
        ohms = (combined*color_multipliers[color3])/(10**3)
        disp = str(ohms) + "k"
    if ohms >= 10**6:
        ohms = (combined*color_multipliers[color3])/(10**6)
        disp = str(ohms) + "M"

        
        
    #Filter out value noise, list -> most frequent element gets printed to reduce twitching    
    ohms_list.append(disp)
    if ohms == 0:
        pass
    else:
        ohms = max(ohms_list, key=ohms_list.count)
    
    if len(ohms_list) > 50:
        print("list reset")
        ohms_list = [ohms]
        
        
    #print(ohms_list)
    #print(len(ohms_list), " length")
    
    disp_colors = str("Colors: " + color1 + " " + color2 + " * " + color3)
    
    cv2.putText(show_frame,disp + ' ohm',(0,int(height*0.9)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    print("output: " + disp)
    cv2.putText(show_frame,disp_colors,(int(width*0.75),int(height*0.9)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    print(show_frame.shape)
    cv2.imshow("result",show_frame)
    
    #Close window
    key = cv2.waitKey(1) 
    if key == 27:
        break
    
        print(colors)
    
        
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 792.0
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 253.0
# brown 61.0
# dark brown
# [0, 63, 77]  sorted and before pop
# [0, 63, 77]  sorted and after pop
# Colors:  Black Black  *  Brown
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 792.0
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 52.5
# orange 47.0
# [0, 68, 92]  sorted and before pop
# [0, 68, 92]  sorted and after pop
# Colors:  Black Red  *  Orange
# output: 2.0k
# (1080, 1920, 3)
# 7.5  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 46.0
# [88]  sorted and before pop
# [88]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 48.5
# [77, 88]  sorted and before pop
# [77, 88]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 32.5
# red 42.0
# 0.0  lila
# 0.0  lila
# [73, 77, 88, 94]  sorted and before pop
# reached if pop
# popped:  77
# [73, 88, 94]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# red 42.5
# red 42.0
# 15.0  lila
# [68, 88]  sorted and before pop
# [68, 88]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 44.0
# 31.5  lila
# [60, 68, 83, 88]  sorted and before pop
# reached if pop
# popped:  68
# [60, 83, 88]  sorted and after pop
# Colors:  Red Violet  *  Red
# output: 2.7k
# (1080, 1920, 3)
# red 60.0
# red 45.0
# orange 47.0
# 0.0  lila
# 0.0  lila
# [52, 74, 92]  sorted and before pop
# [52, 74, 92]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 52.0
# 20.0  lila
# [42]  sorted and before pop
# [42]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 71.0
# red 46.0
# orange 51.5
# 0.0  lila
# [37, 42, 60, 79]  sorted and before pop
# reached if pop
# popped:  42
# [37, 60, 79]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 48.0
# orange 62.5
# 43.0  lila
# [30, 53, 72]  sorted and before pop
# [30, 53, 72]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# red 39.5
# red 49.5
# orange 43.0
# 18.0  lila
# [29, 52, 72]  sorted and before pop
# [29, 52, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 43.0
# orange 66.0
# 37.0  lila
# [28, 52, 70]  sorted and before pop
# [28, 52, 70]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# red 67.5
# red 48.0
# 4.0  lila
# [26, 48]  sorted and before pop
# [26, 48]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 38.0
# red 53.0
# orange 33.0
# 20.5  lila
# [26, 48, 49, 72]  sorted and before pop
# reached if pop
# popped:  48
# [26, 49, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 55.5
# red 40.0
# orange 63.0
# 11.5  lila
# [22, 45, 63]  sorted and before pop
# [22, 45, 63]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 68.5
# red 42.5
# orange 55.0
# [19, 41, 61]  sorted and before pop
# [19, 41, 61]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 35.5
# red 41.0
# orange 69.5
# 16.5  lila
# [17, 39, 59]  sorted and before pop
# [17, 39, 59]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 54.5
# orange 47.0
# 16.0  lila
# [17, 59]  sorted and before pop
# [17, 59]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 43.0
# 7.5  lila
# [14, 17, 59]  sorted and before pop
# [14, 17, 59]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 49.0
# 0.0  lila
# [12]  sorted and before pop
# [12]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 47.0
# 0.0  lila
# [11, 12]  sorted and before pop
# [11, 12]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 47.0
# 3.0  lila
# [11, 12]  sorted and before pop
# [11, 12]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 45.5
# 0.0  lila
# [11, 12]  sorted and before pop
# [11, 12]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 41.0
# 0.0  lila
# [11, 12]  sorted and before pop
# [11, 12]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 44.5
# red 55.0
# orange 34.0
# 9.0  lila
# [11, 12, 32, 54]  sorted and before pop
# reached if pop
# popped:  12
# [11, 32, 54]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 57.5
# red 53.5
# orange 60.0
# 19.0  lila
# [9, 31, 51]  sorted and before pop
# [9, 31, 51]  sorted and after pop
# Colors:  Red Red  *  Orange
# list reset
# output: 22.0k
# (1080, 1920, 3)
# red 46.0
# red 74.0
# orange 52.5
# 0.0  lila
# 0.0  lila
# [8, 30, 50]  sorted and before pop
# [8, 30, 50]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# 5.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 41.5
# [31]  sorted and before pop
# [31]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 5.0  lila
# [31]  sorted and before pop
# [31]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# [31]  sorted and before pop
# [31]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 60.0
# orange 34.0
# 0.0  lila
# 0.0  lila
# 0.0  lila
# [31, 32, 51]  sorted and before pop
# [31, 32, 51]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 51.5
# orange 60.5
# 49.0  lila
# [10, 33, 53]  sorted and before pop
# [10, 33, 53]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# red 56.5
# orange 70.5
# 44.0  lila
# [13, 37, 55]  sorted and before pop
# [13, 37, 55]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# red 75.0
# red 34.0
# orange 32.5
# 3.5  lila
# 0.0  lila
# [16, 37, 59]  sorted and before pop
# [16, 37, 59]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 36.5
# red 50.5
# orange 36.0
# 12.0  lila
# [18, 40, 61]  sorted and before pop
# [18, 40, 61]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 31.5
# red 52.0
# 0.0  lila
# [19, 41]  sorted and before pop
# [19, 41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 54.5
# 0.0  lila
# [18, 19, 41]  sorted and before pop
# [18, 19, 41]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# red 53.5
# 0.0  lila
# [19]  sorted and before pop
# [19]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 47.5
# 0.0  lila
# 4.5  lila
# [17, 19]  sorted and before pop
# [17, 19]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 43.0
# 0.0  lila
# [17, 18, 19]  sorted and before pop
# [17, 18, 19]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# red 45.0
# orange 40.0
# [17, 60]  sorted and before pop
# [17, 60]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 49.5
# red 45.5
# orange 63.5
# [17, 19, 42, 60]  sorted and before pop
# reached if pop
# popped:  19
# [17, 42, 60]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 57.5
# red 53.5
# orange 67.5
# 0.0  lila
# [20, 41, 61]  sorted and before pop
# [20, 41, 61]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 37.0
# red 30.5
# 0.0  lila
# 18.5  lila
# [20, 43]  sorted and before pop
# [20, 43]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 52.0
# orange 69.0
# 30.5  lila
# [18, 20, 42, 43, 60]  sorted and before pop
# reached if pop
# popped:  20
# reached if pop
# popped:  43
# [18, 42, 60]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# red 47.0
# orange 41.0
# 22.5  lila
# [19, 60]  sorted and before pop
# [19, 60]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 53.0
# orange 60.0
# 22.5  lila
# [18, 19, 60, 61]  sorted and before pop
# reached if pop
# popped:  19
# [18, 60, 61]  sorted and after pop
# Colors:  Red Orange  *  Orange
# output: 23.0k
# (1080, 1920, 3)
# red 52.0
# orange 46.0
# 25.5  lila
# [17, 60]  sorted and before pop
# [17, 60]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 52.0
# orange 49.5
# 44.5  lila
# [17, 40, 60]  sorted and before pop
# [17, 40, 60]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# orange 64.0
# 34.0  lila
# 0.0  lila
# [40, 60]  sorted and before pop
# [40, 60]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 60.0
# red 52.0
# orange 54.5
# 7.5  lila
# [17, 40, 60]  sorted and before pop
# [17, 40, 60]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# red 47.0
# 26.5  lila
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 54.0
# orange 64.5
# 10.5  lila
# 9.0  lila
# [20, 43, 61]  sorted and before pop
# [20, 43, 61]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 55.5
# red 40.0
# orange 59.0
# 11.5  lila
# [22, 45, 63]  sorted and before pop
# [22, 45, 63]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 55.5
# red 44.0
# orange 63.0
# 11.5  lila
# [21, 45, 63]  sorted and before pop
# [21, 45, 63]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 76.0
# red 40.0
# orange 60.0
# 6.0  lila
# [23, 45, 64]  sorted and before pop
# [23, 45, 64]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 75.0
# red 46.5
# orange 53.5
# 0.0  lila
# [21, 43, 63]  sorted and before pop
# [21, 43, 63]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 20.0
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 51.0
# green 51.0
# green 0.0
# black 49.5
# dark brown
# [3, 22, 39]  sorted and before pop
# [3, 22, 39]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 27.5
# black 33.0
# black 76.0
# dark brown
# [12, 30, 51]  sorted and before pop
# [12, 30, 51]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# green 30.0
# black 34.5
# black 58.0
# black 33.5
# brown 41.0
# dark brown
# [13, 14, 15, 33, 52]  sorted and before pop
# reached if pop
# popped:  14
# reached if pop
# popped:  33
# [13, 15, 52]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# green 0.0
# green 0.0
# green 49.0
# green 49.0
# black 53.5
# brown 37.5
# dark brown
# [16, 35, 53]  sorted and before pop
# [16, 35, 53]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 11.0
# 7.5  lila
# dark brown
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 14.0  lila
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 23.0  lila
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# 6.0  lila
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 4.0
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 6.0
# 0.0  lila
# dark brown
# [11]  sorted and before pop
# [11]  sorted and after pop
# reached if
# list reset
# output: 0
# (1080, 1920, 3)
# green 0.0
# green 0.0
# green 51.0
# green 51.0
# black 31.5
# dark brown
# [11, 12, 31, 48]  sorted and before pop
# reached if pop
# popped:  12
# [11, 31, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 64.5
# green 64.5
# black 62.5
# brown 38.0
# dark brown
# [13, 14, 32, 48]  sorted and before pop
# reached if pop
# popped:  14
# [13, 32, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 55.0
# green 55.0
# black 73.0
# dark brown
# [14, 32, 48]  sorted and before pop
# [14, 32, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 66.5
# green 66.5
# black 63.5
# brown 38.0
# dark brown
# [13, 14, 32, 48]  sorted and before pop
# reached if pop
# popped:  14
# [13, 32, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 0.0
# green 0.0
# green 20.0
# black 72.0
# [32]  sorted and before pop
# [32]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 29.0
# black 62.0
# brown 37.5
# dark brown
# [14, 32, 33]  sorted and before pop
# [14, 32, 33]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# green 54.0
# green 54.0
# black 67.0
# brown 37.0
# dark brown
# [12, 13, 31, 48]  sorted and before pop
# reached if pop
# popped:  13
# [12, 31, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 61.0
# green 61.0
# green 0.0
# black 69.5
# brown 43.5
# dark brown
# [12, 31, 48]  sorted and before pop
# [12, 31, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 68.5
# green 68.5
# green 0.0
# black 60.5
# brown 42.0
# dark brown
# [12, 13, 31, 48]  sorted and before pop
# reached if pop
# popped:  13
# [12, 31, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 79.0
# green 79.0
# black 62.0
# brown 47.0
# dark brown
# [13, 14, 32, 48]  sorted and before pop
# reached if pop
# popped:  14
# [13, 32, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 30.5
# green 30.5
# black 66.5
# dark brown
# [14, 33, 50]  sorted and before pop
# [14, 33, 50]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 74.0
# green 74.0
# black 56.0
# brown 35.0
# dark brown
# [13, 14, 32, 49]  sorted and before pop
# reached if pop
# popped:  14
# [13, 32, 49]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 32.0
# green 32.0
# black 65.0
# brown 38.5
# dark brown
# [13, 14, 33, 50]  sorted and before pop
# reached if pop
# popped:  14
# [13, 33, 50]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 58.5
# green 58.5
# black 66.5
# brown 37.5
# dark brown
# [14, 15, 33, 51]  sorted and before pop
# reached if pop
# popped:  15
# [14, 33, 51]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 62.5
# green 62.5
# black 66.5
# dark brown
# [14, 32, 48]  sorted and before pop
# [14, 32, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 56.5
# green 56.5
# green 0.0
# black 65.0
# brown 32.0
# dark brown
# [12, 30, 48]  sorted and before pop
# [12, 30, 48]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 75.0
# green 75.0
# 0.0  lila
# 4.0  lila
# black 56.5
# brown 41.5
# dark brown
# [6, 25, 41]  sorted and before pop
# [6, 25, 41]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 10.5
# 0.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 53.0
# [92]  sorted and before pop
# [92]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 92.5
# 44.0  lila
# [48, 77, 92]  sorted and before pop
# [48, 77, 92]  sorted and after pop
# Colors:  Yellow Violet  *  Yellow
# output: 470.0k
# (1080, 1920, 3)
# yellow 89.5
# 16.5  lila
# [16]  sorted and before pop
# [16]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 24.0  lila
# [16]  sorted and before pop
# [16]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [16]  sorted and before pop
# [16]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 4.0  lila
# 0.0  lila
# 0.0  lila
# [16]  sorted and before pop
# [16]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 18.0  lila
# 14.5  lila
# 0.0  lila
# [16]  sorted and before pop
# [16]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 13.5  lila
# [16]  sorted and before pop
# [16]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 32.0
# 52.5  lila
# [0, 16, 19]  sorted and before pop
# [0, 16, 19]  sorted and after pop
# Colors:  Yellow Yellow  *  Violet
# output: 440.0M
# (1080, 1920, 3)
# red 32.0
# yellow 54.5
# 0.0  lila
# 4.0  lila
# 32.5  lila
# [0, 26, 46]  sorted and before pop
# [0, 26, 46]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 32.0
# yellow 111.0
# 48.0  lila
# [0, 29, 47]  sorted and before pop
# [0, 29, 47]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 42.0
# yellow 94.0
# 41.0  lila
# [4, 33, 51]  sorted and before pop
# [4, 33, 51]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# yellow 84.0
# 16.5  lila
# [12]  sorted and before pop
# [12]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 102.0
# 28.0  lila
# [12, 16]  sorted and before pop
# [12, 16]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 91.0
# 48.0  lila
# [12, 16, 45]  sorted and before pop
# [12, 16, 45]  sorted and after pop
# Colors:  Yellow Yellow  *  Violet
# output: 440.0M
# (1080, 1920, 3)
# yellow 95.5
# 51.0  lila
# [21, 48]  sorted and before pop
# [21, 48]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 102.0
# orange 54.0
# 56.5  lila
# [21, 48, 50, 65]  sorted and before pop
# reached if pop
# popped:  48
# [21, 50, 65]  sorted and after pop
# Colors:  Yellow Violet  *  Orange
# output: 47.0k
# (1080, 1920, 3)
# red 52.0
# yellow 73.0
# 48.5  lila
# red dark 39.5
# [21, 50, 69]  sorted and before pop
# [21, 50, 69]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# yellow 96.5
# 62.0  lila
# [27, 50]  sorted and before pop
# [27, 50]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 42.5
# yellow 98.5
# 56.5  lila
# [23, 27, 50, 51, 69]  sorted and before pop
# reached if pop
# popped:  27
# reached if pop
# popped:  51
# [23, 50, 69]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 47.0
# yellow 74.5
# 35.0  lila
# [25, 50, 70]  sorted and before pop
# [25, 50, 70]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 45.0
# yellow 96.5
# 46.5  lila
# [21, 51, 68]  sorted and before pop
# [21, 51, 68]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 35.0
# yellow 132.5
# 24.5  lila
# [22, 70]  sorted and before pop
# [22, 70]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 45.5
# yellow 96.0
# 46.5  lila
# [22, 23, 51, 68, 70]  sorted and before pop
# reached if pop
# popped:  23
# reached if pop
# popped:  68
# [22, 51, 70]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# list reset
# output: 4.7k
# (1080, 1920, 3)
# red 48.0
# yellow 31.5
# 29.5  lila
# [18, 66]  sorted and before pop
# [18, 66]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 41.0
# yellow 58.0
# 49.5  lila
# [18, 20, 48, 66]  sorted and before pop
# reached if pop
# popped:  20
# [18, 48, 66]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 56.5
# yellow 52.5
# 39.0  lila
# 0.0  lila
# [20, 50, 65]  sorted and before pop
# [20, 50, 65]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 46.0
# yellow 49.0
# 49.5  lila
# [20, 48, 66]  sorted and before pop
# [20, 48, 66]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 53.0
# 0.0  lila
# 0.0  lila
# 41.0  lila
# [48, 67]  sorted and before pop
# [48, 67]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 39.5
# 26.5  lila
# 2.5  lila
# [48, 67, 68]  sorted and before pop
# [48, 67, 68]  sorted and after pop
# Colors:  Violet Red  *  Red
# output: 7.2k
# (1080, 1920, 3)
# red 34.5
# 0.0  lila
# 0.0  lila
# [68]  sorted and before pop
# [68]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# 9.0  lila
# [68]  sorted and before pop
# [68]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 36.5
# 12.5  lila
# 0.0  lila
# 12.5  lila
# [68, 71]  sorted and before pop
# [68, 71]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 31.5
# 2.0  lila
# [68, 71, 72]  sorted and before pop
# [68, 71, 72]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# 0.0  lila
# 0.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# 7.5  lila
# 0.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 56.5
# 44.0  lila
# [0, 16]  sorted and before pop
# [0, 16]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 57.0
# 58.0  lila
# [0, 5, 16, 24]  sorted and before pop
# reached if pop
# popped:  5
# [0, 16, 24]  sorted and after pop
# Colors:  Violet Red  *  Red
# output: 7.2k
# (1080, 1920, 3)
# 0.0  lila
# 72.0  lila
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 64.5
# 30.0  lila
# [0, 20]  sorted and before pop
# [0, 20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 57.5
# 0.0  lila
# 69.0  lila
# [0, 11, 20, 40]  sorted and before pop
# reached if pop
# popped:  11
# [0, 20, 40]  sorted and after pop
# Colors:  Yellow Violet  *  Violet
# output: 470.0M
# (1080, 1920, 3)
# yellow 56.0
# 54.0  lila
# [15, 45]  sorted and before pop
# [15, 45]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 81.0
# 65.5  lila
# [15, 16, 45, 46]  sorted and before pop
# reached if pop
# popped:  16
# [15, 45, 46]  sorted and after pop
# Colors:  Yellow Violet  *  Violet
# output: 470.0M
# (1080, 1920, 3)
# red 30.5
# yellow 77.5
# 56.0  lila
# [15, 48, 66]  sorted and before pop
# [15, 48, 66]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 42.5
# yellow 117.0
# 52.5  lila
# [18, 49, 67]  sorted and before pop
# [18, 49, 67]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 45.5
# yellow 128.5
# 64.0  lila
# [17, 49, 67]  sorted and before pop
# [17, 49, 67]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 42.5
# yellow 101.5
# 0.0  lila
# 72.0  lila
# [18, 48, 67]  sorted and before pop
# [18, 48, 67]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 45.0
# yellow 88.0
# 63.0  lila
# [20, 50, 68]  sorted and before pop
# [20, 50, 68]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 40.5
# yellow 118.0
# 0.0  lila
# 71.5  lila
# [15, 49, 68]  sorted and before pop
# [15, 49, 68]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 44.0
# yellow 114.5
# 72.0  lila
# [17, 49, 68]  sorted and before pop
# [17, 49, 68]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 44.0
# yellow 73.0
# 63.5  lila
# [19, 50, 68]  sorted and before pop
# [19, 50, 68]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 41.5
# yellow 96.0
# 0.0  lila
# 64.0  lila
# [18, 48, 67]  sorted and before pop
# [18, 48, 67]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 51.0
# yellow 68.5
# 56.0  lila
# [17, 47, 65]  sorted and before pop
# [17, 47, 65]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# 53.0  lila
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [7]  sorted and before pop
# [7]  sorted and after pop
# reached if
# list reset
# output: 0
# (1080, 1920, 3)
# yellow 42.5
# 39.0  lila
# [7, 40, 66]  sorted and before pop
# [7, 40, 66]  sorted and after pop
# Colors:  Violet Yellow  *  Violet
# output: 740.0M
# (1080, 1920, 3)
# 6.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 52.0
# yellow 104.5
# 56.0  lila
# [19, 48, 65]  sorted and before pop
# [19, 48, 65]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 38.0
# yellow 37.0
# 64.0  lila
# [12, 40, 57]  sorted and before pop
# [12, 40, 57]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 42.5
# yellow 72.5
# 72.0  lila
# [6, 34, 52]  sorted and before pop
# [6, 34, 52]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# 0.0  lila
# 56.0  lila
# [36]  sorted and before pop
# [36]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# 48.0  lila
# [36, 39]  sorted and before pop
# [36, 39]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 65.0
# 44.0  lila
# [14, 36, 39, 42]  sorted and before pop
# reached if pop
# popped:  36
# [14, 39, 42]  sorted and after pop
# Colors:  Yellow Violet  *  Violet
# output: 470.0M
# (1080, 1920, 3)
# red 49.0
# yellow 81.5
# 64.0  lila
# [12, 40, 58]  sorted and before pop
# [12, 40, 58]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 37.0
# yellow 64.0
# 72.0  lila
# [17, 44, 60]  sorted and before pop
# [17, 44, 60]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 39.0
# yellow 76.0
# 56.0  lila
# [17, 48, 65]  sorted and before pop
# [17, 48, 65]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 33.5
# yellow 72.0
# 68.0  lila
# [23, 50, 68]  sorted and before pop
# [23, 50, 68]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 36.0
# yellow 72.0
# 72.0  lila
# [23, 49, 67]  sorted and before pop
# [23, 49, 67]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# yellow 53.0
# 0.0  lila
# 56.0  lila
# [26, 52]  sorted and before pop
# [26, 52]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 71.5
# 0.0  lila
# 58.5  lila
# [26, 27, 52, 54]  sorted and before pop
# reached if pop
# popped:  27
# [26, 52, 54]  sorted and after pop
# Colors:  Yellow Violet  *  Violet
# output: 470.0M
# (1080, 1920, 3)
# yellow 67.0
# 0.0  lila
# 54.5  lila
# [27, 55]  sorted and before pop
# [27, 55]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 60.0
# 61.0  lila
# [27, 28, 55]  sorted and before pop
# [27, 28, 55]  sorted and after pop
# Colors:  Yellow Yellow  *  Violet
# output: 440.0M
# (1080, 1920, 3)
# yellow 68.0
# 0.0  lila
# 54.5  lila
# [28, 54]  sorted and before pop
# [28, 54]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 64.0
# 0.0  lila
# 51.0  lila
# [28, 54]  sorted and before pop
# [28, 54]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 34.0
# yellow 44.5
# 48.0  lila
# [27, 28, 54, 71]  sorted and before pop
# reached if pop
# popped:  28
# [27, 54, 71]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 34.0
# yellow 36.0
# 52.0  lila
# [27, 54, 70]  sorted and before pop
# [27, 54, 70]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 33.0
# yellow 51.0
# 63.0  lila
# [27, 54, 70]  sorted and before pop
# [27, 54, 70]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 41.0
# yellow 52.0
# 0.0  lila
# 44.0  lila
# [27, 54, 70]  sorted and before pop
# [27, 54, 70]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 34.0
# yellow 56.5
# 52.0  lila
# [26, 54, 70]  sorted and before pop
# [26, 54, 70]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 38.5
# yellow 50.0
# 44.0  lila
# [27, 54, 70]  sorted and before pop
# [27, 54, 70]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# red 36.0
# yellow 61.0
# 44.0  lila
# [26, 54, 70]  sorted and before pop
# [26, 54, 70]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# yellow 76.0
# 60.5  lila
# [23, 52]  sorted and before pop
# [23, 52]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 43.5
# yellow 81.0
# 52.0  lila
# [19, 23, 49, 52, 65]  sorted and before pop
# reached if pop
# popped:  23
# reached if pop
# popped:  52
# [19, 49, 65]  sorted and after pop
# Colors:  Yellow Violet  *  Red
# output: 4.7k
# (1080, 1920, 3)
# 0.0  lila
# 0.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 16.0
# black 73.5
# brown 79.0
# dark brown
# [46, 47, 76]  sorted and before pop
# [46, 47, 76]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# green 37.5
# green 37.5
# green 0.0
# black 72.0
# brown 68.5
# [41, 71, 92]  sorted and before pop
# [41, 71, 92]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 7.0
# green 11.0
# black 38.0
# black 74.0
# brown 85.0
# dark brown
# [39, 40, 69, 91]  sorted and before pop
# reached if pop
# popped:  40
# [39, 69, 91]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# green 25.0
# green 0.0
# black 72.0
# brown 41.0
# [41, 71]  sorted and before pop
# [41, 71]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 33.5
# green 33.5
# black 72.0
# brown 75.0
# brown 39.0
# [39, 40, 41, 70, 71, 90]  sorted and before pop
# reached if pop
# popped:  40
# reached if pop
# popped:  70
# reached if pop
# popped:  90
# [39, 41, 71]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# green 0.0
# green 28.5
# black 72.0
# brown 40.5
# [37, 68]  sorted and before pop
# [37, 68]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 36.0
# green 36.0
# black 70.5
# brown 60.5
# [37, 39, 68, 70, 90]  sorted and before pop
# reached if pop
# popped:  39
# reached if pop
# popped:  70
# [37, 68, 90]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 0.0
# green 17.5
# 0.0  lila
# black 68.0
# brown 69.0
# [39, 70]  sorted and before pop
# [39, 70]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 3.0
# green 9.5
# black 73.5
# brown 66.5
# [38, 39, 68, 70]  sorted and before pop
# reached if pop
# popped:  39
# [38, 68, 70]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# green 5.0
# green 25.5
# black 72.0
# brown 77.0
# dark brown
# [32, 33, 63]  sorted and before pop
# [32, 33, 63]  sorted and after pop
# Colors:  Brown Brown  *  Black
# list reset
# output: 11
# (1080, 1920, 3)
# green 36.0
# green 36.0
# black 68.0
# brown 67.0
# [26, 57, 77]  sorted and before pop
# [26, 57, 77]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 44.0
# green 44.0
# black 67.0
# brown 52.0
# [14, 45, 65]  sorted and before pop
# [14, 45, 65]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 22.5
# black 70.0
# brown 48.0
# [6, 37]  sorted and before pop
# [6, 37]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 28.0
# green 0.0
# black 72.0
# brown 40.5
# [6, 10, 37, 41]  sorted and before pop
# reached if pop
# popped:  10
# [6, 37, 41]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# green 35.0
# green 35.0
# black 69.0
# brown 86.0
# brown 37.5
# [14, 15, 46, 66]  sorted and before pop
# reached if pop
# popped:  15
# [14, 46, 66]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 40.0
# green 40.0
# green 0.0
# black 69.0
# brown 80.0
# brown 35.5
# [18, 19, 49, 70]  sorted and before pop
# reached if pop
# popped:  19
# [18, 49, 70]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 44.0
# green 44.0
# green 0.0
# black 73.0
# brown 50.0
# [18, 49, 70]  sorted and before pop
# [18, 49, 70]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 44.5
# green 44.5
# black 69.0
# brown 56.0
# [18, 49, 70]  sorted and before pop
# [18, 49, 70]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 42.0
# green 42.0
# black 72.0
# brown 53.5
# [18, 49, 70]  sorted and before pop
# [18, 49, 70]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 45.0
# green 45.0
# black 71.0
# brown 51.5
# [18, 49, 70]  sorted and before pop
# [18, 49, 70]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 40.0
# green 40.0
# 0.0  lila
# black 73.5
# brown 50.5
# [20, 51, 71]  sorted and before pop
# [20, 51, 71]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 37.0
# green 37.0
# green 0.0
# black 70.0
# brown 59.5
# [22, 53, 74]  sorted and before pop
# [22, 53, 74]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 33.5
# green 33.5
# black 78.5
# brown 68.0
# [22, 52, 73]  sorted and before pop
# [22, 52, 73]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 22.0
# black 76.0
# brown 78.5
# dark brown
# [19, 20, 49]  sorted and before pop
# [19, 20, 49]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 53.5
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# orange 48.0
# black 64.0
# [17, 20, 33]  sorted and before pop
# [17, 20, 33]  sorted and after pop
# Colors:  Black Black  *  Orange
# output: 0
# (1080, 1920, 3)
# orange 47.5
# black 68.0
# brown 52.5
# [2, 28, 44]  sorted and before pop
# [2, 28, 44]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 51.0
# black 63.0
# brown 54.5
# [10, 36, 53]  sorted and before pop
# [10, 36, 53]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 57.0
# black 63.0
# brown 59.0
# dark brown
# [14, 16, 40, 57]  sorted and before pop
# reached if pop
# popped:  16
# [14, 40, 57]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# black 56.0
# brown 64.0
# dark brown
# [24, 25, 50]  sorted and before pop
# [24, 25, 50]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# black 58.5
# brown 59.0
# dark brown
# [27, 28, 53]  sorted and before pop
# [27, 28, 53]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# orange 34.0
# black 57.5
# brown 64.0
# dark brown
# [32, 33, 57, 75]  sorted and before pop
# reached if pop
# popped:  33
# [32, 57, 75]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# black 64.0
# brown 33.0
# [35, 60]  sorted and before pop
# [35, 60]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 58.0
# brown 60.0
# dark brown
# [34, 35, 59, 60]  sorted and before pop
# reached if pop
# popped:  35
# [34, 59, 60]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# black 59.5
# brown 53.0
# dark brown
# [33, 34, 59]  sorted and before pop
# [33, 34, 59]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# orange 34.5
# black 45.0
# brown 52.0
# dark brown
# [33, 34, 59, 76]  sorted and before pop
# reached if pop
# popped:  34
# [33, 59, 76]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 32.0
# black 60.0
# brown 64.0
# dark brown
# [32, 33, 58, 75]  sorted and before pop
# reached if pop
# popped:  33
# [32, 58, 75]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 36.0
# black 68.0
# brown 32.0
# dark brown
# [31, 32, 56, 73]  sorted and before pop
# reached if pop
# popped:  32
# [31, 56, 73]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 37.5
# black 60.0
# brown 60.0
# dark brown
# [32, 33, 58, 75]  sorted and before pop
# reached if pop
# popped:  33
# [32, 58, 75]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 51.0
# black 63.5
# brown 36.0
# dark brown
# [31, 32, 56, 73]  sorted and before pop
# reached if pop
# popped:  32
# [31, 56, 73]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 44.0
# black 61.5
# brown 40.0
# dark brown
# [30, 31, 56, 72]  sorted and before pop
# reached if pop
# popped:  31
# [30, 56, 72]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 49.0
# black 62.5
# brown 40.0
# dark brown
# [30, 31, 55, 72]  sorted and before pop
# reached if pop
# popped:  31
# [30, 55, 72]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 35.0
# black 63.5
# [41, 57]  sorted and before pop
# [41, 57]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41, 57]  sorted and before pop
# [41, 57]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# 0.0  lila
# 9.0  lila
# [41, 57]  sorted and before pop
# [41, 57]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# [41, 57]  sorted and before pop
# [41, 57]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 64.0
# black 33.0
# [41, 57, 70, 87]  sorted and before pop
# reached if pop
# popped:  57
# [41, 70, 87]  sorted and after pop
# Colors:  Black Black  *  Yellow
# output: 0
# (1080, 1920, 3)
# yellow 84.5
# black 37.5
# brown 50.0
# dark brown
# [43, 44, 68, 87]  sorted and before pop
# reached if pop
# popped:  44
# [43, 68, 87]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 64.5
# black 41.0
# brown 44.5
# dark brown
# [34, 35, 62, 81]  sorted and before pop
# reached if pop
# popped:  35
# [34, 62, 81]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 71.0
# black 39.0
# [62, 76]  sorted and before pop
# [62, 76]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# 3.0  lila
# [62, 76]  sorted and before pop
# [62, 76]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# 0.0  lila
# brown 34.0
# [40, 62, 76]  sorted and before pop
# [40, 62, 76]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# brown 38.0
# [43]  sorted and before pop
# [43]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# 0.0  lila
# brown 41.0
# [43, 44]  sorted and before pop
# [43, 44]  sorted and after pop
# reached if
# list reset
# output: 0
# (1080, 1920, 3)
# [43, 44]  sorted and before pop
# [43, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 36.0
# black 32.0
# brown 43.0
# [42, 43, 44, 66, 79]  sorted and before pop
# reached if pop
# popped:  43
# reached if pop
# popped:  66
# [42, 44, 79]  sorted and after pop
# Colors:  Brown Brown  *  Yellow
# output: 110.0k
# (1080, 1920, 3)
# yellow 42.5
# black 35.0
# brown 30.5
# [39, 63, 76]  sorted and before pop
# [39, 63, 76]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 81.5
# black 40.0
# brown 39.0
# [37, 61, 76]  sorted and before pop
# [37, 61, 76]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 47.0
# black 39.0
# brown 32.0
# [39, 62, 79]  sorted and before pop
# [39, 62, 79]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 92.0
# black 40.0
# brown 31.0
# [39, 62, 76]  sorted and before pop
# [39, 62, 76]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 72.0
# brown 42.0
# [33, 76]  sorted and before pop
# [33, 76]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# yellow 49.0
# black 31.0
# brown 49.0
# [31, 33, 57, 75, 76]  sorted and before pop
# reached if pop
# popped:  33
# reached if pop
# popped:  75
# [31, 57, 76]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 73.0
# black 33.0
# brown 38.0
# [34, 61, 76]  sorted and before pop
# [34, 61, 76]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 78.5
# black 31.0
# brown 50.5
# [32, 59, 75]  sorted and before pop
# [32, 59, 75]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 56.0
# brown 47.0
# dark brown
# [31, 58, 76]  sorted and before pop
# [31, 58, 76]  sorted and after pop
# Colors:  Brown Brown  *  Yellow
# output: 110.0k
# (1080, 1920, 3)
# yellow 72.0
# black 32.5
# brown 46.5
# [33, 60, 75]  sorted and before pop
# [33, 60, 75]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 45.0
# black 32.0
# brown 49.0
# [31, 57, 75]  sorted and before pop
# [31, 57, 75]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 56.0
# brown 50.5
# dark brown
# [31, 60, 76]  sorted and before pop
# [31, 60, 76]  sorted and after pop
# Colors:  Brown Brown  *  Yellow
# output: 110.0k
# (1080, 1920, 3)
# yellow 80.0
# black 32.0
# brown 49.0
# [34, 60, 76]  sorted and before pop
# [34, 60, 76]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# yellow 64.5
# black 42.5
# [59, 78]  sorted and before pop
# [59, 78]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [59, 78]  sorted and before pop
# [59, 78]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [59, 78]  sorted and before pop
# [59, 78]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [59, 78]  sorted and before pop
# [59, 78]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# dark brown
# [0, 59, 78]  sorted and before pop
# [0, 59, 78]  sorted and after pop
# Colors:  Brown Black  *  Yellow
# output: 100.0k
# (1080, 1920, 3)
# black 63.0
# [86]  sorted and before pop
# [86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [86]  sorted and before pop
# [86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [86]  sorted and before pop
# [86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [86]  sorted and before pop
# [86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [86]  sorted and before pop
# [86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [86]  sorted and before pop
# [86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [86]  sorted and before pop
# [86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [86]  sorted and before pop
# [86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 792.0
# [0, 86]  sorted and before pop
# [0, 86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0, 86]  sorted and before pop
# [0, 86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0, 86]  sorted and before pop
# [0, 86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0, 86]  sorted and before pop
# [0, 86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0, 86]  sorted and before pop
# [0, 86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0, 86]  sorted and before pop
# [0, 86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0, 86]  sorted and before pop
# [0, 86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0, 86]  sorted and before pop
# [0, 86]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-3b72bc5c6392> in <module>
#     433
#     434
# --> 435 cap.release()
#     436 cv2.destroyAllWindows()
#     437 cv2.waitKey(1)
#
# NameError: name 'cap' is not defined

# %%
test = ['0', '2.0M', '12', '0', '12', '1.0M', '21', '1.0M', '12', '21', '12', '12', '12', 
        '1.0M', '2.0M', '1.0M', '0', '1.0M', '2.0M', '1.0M', 
         '200.0k', '1.0M', '2.0M', '1.0M', 
        '1.0M', '12', '12', '21', '1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '2.0M', 
        '1.0M', '2.0M', '1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '12', '1.0M', '2.0M', '0',  
         '1.0M','10', '1.0M', '0', '0', '0', 
        '0', '700.0k', '1.0M', '1.0M', '1.0M', '0', '0', '0', '10', '0', '0', '0', '0', '0', 
        '10', '700.0k', '11', '1.0M', '0', '0', '1.0M', '0', '1.0M', '0', '0', '0', '0', '0', 
        ]
test_max = max(test, key=test.count)
print(test_max)
# Out:
# 1.0M
