# %%
# %matplotlib auto
import numpy as np
import cv2
from keras.preprocessing.image import ImageDataGenerator

from skimage import io
import os
from skimage.filters import threshold_yen
from skimage.exposure import rescale_intensity
from skimage.io import imread, imsave
from matplotlib import pyplot as plt 

from PIL import Image
import imutils
# Out:
# Using matplotlib backend: Qt5Agg

# %%
import requests
address = 'http://192.168.0.30:8080/shot.jpg'
colors = {}
ohms_list = []
#input = "/Users/oliver/Downloads/resistor_photo.jpeg"

color_bands = {"Black": 0, "Brown": 1, "Red": 2, "Orange": 3, "Yellow": 4, "Green": 5, "Blue": 6, "Violet": 7, "Grey": 8, "White": 9}
color_multipliers = {"Black": 1, "Brown": 10, "Red": 100, "Orange": 1000, "Yellow": 10000, "Green": 100000, "Blue":1000000 , "Violet": 10000000, "Grey": 100000000, "White": 100000000}


temp_start = (900, 545)
temp_end = (1000, 550)


while True:
        
    img_resp = requests.get(address)
    img_arr = np.array(bytearray(img_resp.content), dtype=np.uint8)
    frame = cv2.imdecode(img_arr, -1)
    #frame = cv2.imread(input)
    height, width, channels = frame.shape
    #start = (int(width/2 - 50), int(height/2))
    #end = (int(width/2 + 50),int(height/2) + 30)
    show_frame = frame
    
    cv2.bilateralFilter(frame, 5, 800, 800)
    
    cv2.rectangle(frame, temp_start, temp_end, (255,255,255), 1)
    
    frame = frame[550:560, 900:1000]
    
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)


    lower_blue = np.array([80, 50, 50]) #lower boundry
    upper_blue = np.array([106, 250, 150]) #upper boundry
    
    lower_green = np.array([40, 33, 80]) #lower boundry, original 40,70,80
    upper_green = np.array([80, 115, 255]) #upper boundry, original 70, 255, 255
    
    lower_red = np.array([0, 95, 0]) #0,5,0
    upper_red = np.array([7, 255, 190]) #7,255,189
    
    lower_yellow = np.array([19, 87, 136]) #lower boundry
    upper_yellow = np.array([24, 255, 255]) #upper boundry
    
    lower_orange = np.array([8, 103, 160]) #5, 190, 200
    upper_orange = np.array([14, 170, 255]) #18, 225, 255
    
    lower_violet = np.array([[114, 0, 0]])
    upper_violet = np.array([179, 255, 255])
    
    lower_black = np.array([[0, 0, 0]])
    upper_black = np.array([179, 255, 84])
    
    lower_brown = np.array([7, 72, 0]) #0,100,0
    upper_brown = np.array([13, 255, 145]) #12,255,121
    
    lower_brown_dark = np.array([[8, 38, 0]])
    upper_brown_dark = np.array([15, 255, 114])
    
    lower_black_light = np.array([[0, 0, 0]])
    upper_black_light = np.array([179, 255, 14])
    
    lower_violet_dark = np.array([[92, 74, 0]])
    upper_violet_dark = np.array([174, 255, 255])
    
    lower_red_dark = np.array([171, 65, 50]) 
    upper_red_dark = np.array([180, 250, 150]) 
    
    

    mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)
    mask_red = cv2.inRange(hsv, lower_red, upper_red)
    mask_yellow = cv2.inRange(hsv, lower_yellow, upper_yellow)
    mask_orange = cv2.inRange(hsv, lower_orange, upper_orange)
    mask_violet = cv2.inRange(hsv, lower_violet, upper_violet)
    mask_black = cv2.inRange(hsv, lower_black, upper_black)
    mask_brown = cv2.inRange(hsv, lower_brown, upper_brown)
    mask_brown_light = cv2.inRange(hsv, lower_brown_dark, upper_brown_dark)
    mask_black_light = cv2.inRange(hsv, lower_black_light, upper_black_light)
    mask_violet_dark = cv2.inRange(hsv, lower_violet_dark, upper_violet_dark)
    mask_red_dark = cv2.inRange(hsv, lower_red_dark, upper_red_dark)
    
    contour1 = cv2.findContours(mask_blue, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour1 = imutils.grab_contours(contour1)
    
    contour2 = cv2.findContours(mask_green, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour2 = imutils.grab_contours(contour2)
    
    contour3 = cv2.findContours(mask_red, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour3 = imutils.grab_contours(contour3)
    
    contour4 = cv2.findContours(mask_yellow, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour4 = imutils.grab_contours(contour4)
    
    contour5 = cv2.findContours(mask_orange, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour5 = imutils.grab_contours(contour5)
    
    contour6 = cv2.findContours(mask_violet, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour6 = imutils.grab_contours(contour6)
    
    contour7 = cv2.findContours(mask_black, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour7 = imutils.grab_contours(contour7)
    
    contour8 = cv2.findContours(mask_brown, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour8 = imutils.grab_contours(contour8)
    
    contour9 = cv2.findContours(mask_brown_light, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour9 = imutils.grab_contours(contour9)
    
    contour10 = cv2.findContours(mask_black_light, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour10 = imutils.grab_contours(contour10)
    
    contour11 = cv2.findContours(mask_violet_dark, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour11 = imutils.grab_contours(contour11)
    
    contour12 = cv2.findContours(mask_red_dark, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour12 = imutils.grab_contours(contour12)
    
    area_limit = 30
    brown_area_limit = 30
    
                
    for c in contour1:
        area = cv2.contourArea(c)
        if area > area_limit:
            
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x1,y1,w1,h1 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x1,y1),(x1+w1,y1+h1),(255,255,0),1)
            #cv2.putText(frame, "Blue", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
            
            if x1 not in colors:
                colors[x1] = 'Blue'
                
            
    for c in contour2:
        area = cv2.contourArea(c)
        print("green", area)
        if area > area_limit:
            print("green", area)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])
            
            x2,y2,w2,h2 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x2,y2),(x2+w2,y2+h2),(255,255,0),1)
            #cv2.putText(frame, "Green", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)
            
            if x2 not in colors:
                colors[x2] = 'Green'
    
    for c in contour3:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("red", area)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x3,y3,w3,h3 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x3,y3),(x3+w3,y3+h3),(255,255,0),1)
            #cv2.putText(frame, "Red", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
            
            if x3 not in colors:
                colors[x3] = 'Red'
    
    for c in contour4:
        
        area = cv2.contourArea(c)
        if area > area_limit:
            print("yellow", area)
            
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x4,y4,w4,h4 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x4,y4),(x4+w4,y4+h4),(255,255,0),1)
            #cv2.putText(frame, "Yellow", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 3)
            
            if x4 not in colors:
                colors[x4] = 'Yellow'

    for c in contour5:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("orange", area)
          
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])
            
            x5,y5,w5,h5 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x5,y5),(x5+w5,y5+h5),(255,255,0),1)
            #cv2.putText(frame, "Orange", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (2, 106, 255), 3)
            
            if x5 not in colors:
                colors[x5] = 'Orange'

    
    for c in contour6:
        area = cv2.contourArea(c)
        print(area, " lila")
        if area > area_limit:
        
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x6,y6,w6,h6 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x6,y6),(x6+w6,y6+h6),(255,255,0),1)
            #cv2.putText(frame, "Violet", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (238, 130, 238), 3)
            
            if x6 not in colors:
                colors[x6] = 'Violet'


    for c in contour7:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("black", area)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x7,y7,w7,h7 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x7,y7),(x7+w7,y7+h7),(255,255,0),1)
            #cv2.putText(frame, "Black", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (50, 0, 0), 3)
            
            if x7 not in colors:
                colors[x7] = 'Black'

    
    for c in contour8:
        area = cv2.contourArea(c)
        if area > brown_area_limit:
            print("brown", area)
            
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x8,y8,w8,h8 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x8,y8),(x8+w8,y8+h8),(255,255,0),1)
            #cv2.putText(frame, "Brown", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (42, 42, 165), 3)
            
            if x8 not in colors:
                colors[x8] = 'Brown'

    
    for c in contour9:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("dark brown")

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])
            
            x9,y9,w9,h9 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x9,y9),(x9+w9,y9+h9),(255,255,0),1)
            #cv2.putText(frame, "Brown", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (42, 42, 165), 3)
            
            if x9 not in colors:
                colors[x9] = 'Brown'

    
    for c in contour10:
        area = cv2.contourArea(c)
        #print("black", area)
        if area > area_limit:

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x10,y10,w10,h10 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x10,y10),(x10+w10,y10+h10),(255,255,0),1)
            #cv2.putText(frame, "Black", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 50), 3)
            
            if x10 not in colors:
                colors[x10] = 'Black'

    for c in contour11:
        area = cv2.contourArea(c)
        #if area > 500:
            #print(area)
        if area > area_limit:

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            x11,y11,w11,h11 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x11,y11),(x11+w11,y11+h11),(255,255,0),1)
            #cv2.putText(frame, "Violet", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (238, 130, 238), 3)
            
            #if x11 not in colors:
                #colors[x11] = 'Violet'
                
    for c in contour12:
        area = cv2.contourArea(c)
        #print("red dark", area)
        if area > area_limit:
            print("red dark", area)
            
            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])
            
            x12,y12,w12,h12 = cv2.boundingRect(c)
            #cv2.rectangle(frame,(x12,y12),(x12+w12,y12+h12),(255,255,0),1)
            #cv2.putText(frame, "Red", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
            
            #if x12 not in colors:
                #colors[x12] = 'Red'
        
    
    #Display ohm
    colors_list = []
    for color in colors.keys():
             colors_list.append(color)

    colors_list = sorted(colors_list)
    print(colors_list, " sorted and before pop")
    
    
    #If two of the same colors are almost on the same x-position, chose only one.
    #Remove colors that are near the same X-coordinate (e.g. if there are two 
    #colors detected on the same stripe)
    for i in range(len(colors_list)):
        try:
            if len(colors_list) > 3 and colors_list[i] - (colors_list[i+1]) < 0:
                print("reached if pop")
                test = colors_list.pop(i+1)
                print("popped: ", test)
               
        except IndexError:
            print("index error")

            
    print(colors_list, " sorted and after pop")
    
    
    
    if len(colors_list) <3:
        print("reached if")
        color1 = "Black" # 0 ohm if less than 3 colors detected 
        color2 = "Black"
        color3 = "Black"
                
    else:
        color1 = colors[colors_list[0]]
        color2 = colors[colors_list[1]]
        color3 = colors[colors_list[2]]
        print("Colors: ", color1, color2, " * ", color3)
        colors = {}
        

    combined = int(str(color_bands[color1]) + str(color_bands[color2]))

    ohms = combined*color_multipliers[color3]
    
    if ohms < 10**3:
        ohms = (combined*color_multipliers[color3])
        disp = str(ohms)
    if ohms < 10**6 and ohms > 10**3:
        ohms = (combined*color_multipliers[color3])/(10**3)
        disp = str(ohms) + "k"
    if ohms >= 10**6:
        ohms = (combined*color_multipliers[color3])/(10**6)
        disp = str(ohms) + "M"

        
        
    #Filter out value noise, list -> most frequent element gets printed to reduce twitching    
    ohms_list.append(disp)
    if ohms == 0:
        pass
    else:
        ohms = max(ohms_list, key=ohms_list.count)
    
    if len(ohms_list) > 50:
        print("list reset")
        ohms_list = [ohms]
        
        
    #print(ohms_list)
    #print(len(ohms_list), " length")
    
    disp_colors = str("Colors: " + color1 + " " + color2 + " * " + color3)
    
    cv2.putText(show_frame,disp + ' ohm',(0,int(height*0.9)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    print("output: " + disp)
    cv2.putText(show_frame,disp_colors,(int(width*0.75),int(height*0.9)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    print(show_frame.shape)
    cv2.imshow("result",show_frame)
    
    #Close window
    key = cv2.waitKey(1) 
    if key == 27:
        break
    
        print(colors)
    
        
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 116.0
# black 792.0
# brown 192.0
# brown 436.5
# dark brown
# dark brown
# [0, 60, 75]  sorted and before pop
# [0, 60, 75]  sorted and after pop
# Colors:  Black Red  *  Brown
# output: 20
# (1080, 1920, 3)
# red 792.0
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 792.0
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 792.0
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 792.0
# dark brown
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 792.0
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 6.0  lila
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# orange 53.5
# black 47.0
# [0, 65, 82]  sorted and before pop
# [0, 65, 82]  sorted and after pop
# Colors:  Red Black  *  Orange
# output: 20.0k
# (1080, 1920, 3)
# black 57.0
# brown 64.0
# dark brown
# [36, 38, 64]  sorted and before pop
# [36, 38, 64]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# brown 34.5
# dark brown
# [20, 22]  sorted and before pop
# [20, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 62.0
# brown 68.0
# dark brown
# [20, 22, 31, 32, 59]  sorted and before pop
# reached if pop
# popped:  22
# reached if pop
# popped:  32
# [20, 31, 59]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# black 62.0
# brown 58.5
# dark brown
# [30, 31, 57]  sorted and before pop
# [30, 31, 57]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# brown 38.5
# dark brown
# [35]  sorted and before pop
# [35]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# orange 52.0
# black 75.0
# brown 61.0
# [32, 35, 59, 78]  sorted and before pop
# reached if pop
# popped:  35
# [32, 59, 78]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 59.0
# black 72.0
# brown 55.0
# [31, 58, 75]  sorted and before pop
# [31, 58, 75]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# black 76.0
# brown 66.5
# [25, 52]  sorted and before pop
# [25, 52]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# orange 48.0
# black 69.0
# brown 44.0
# [19, 25, 47, 52, 66]  sorted and before pop
# reached if pop
# popped:  25
# reached if pop
# popped:  52
# [19, 47, 66]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 56.5
# black 66.5
# brown 46.0
# [18, 46, 64]  sorted and before pop
# [18, 46, 64]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# black 56.0
# brown 43.5
# [12, 40]  sorted and before pop
# [12, 40]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 59.5
# brown 43.5
# [12, 39, 40]  sorted and before pop
# [12, 39, 40]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# black 54.0
# brown 58.5
# [11, 38]  sorted and before pop
# [11, 38]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# orange 60.0
# black 68.0
# brown 65.5
# [9, 11, 37, 38, 55]  sorted and before pop
# reached if pop
# popped:  11
# reached if pop
# popped:  38
# [9, 37, 55]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 57.0
# black 62.0
# brown 67.5
# [10, 37, 56]  sorted and before pop
# [10, 37, 56]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 68.0
# black 62.5
# brown 65.5
# [10, 37, 55]  sorted and before pop
# [10, 37, 55]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 52.5
# black 69.0
# brown 64.0
# [9, 36, 53]  sorted and before pop
# [9, 36, 53]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 38.0
# black 62.0
# brown 68.0
# [8, 35, 54]  sorted and before pop
# [8, 35, 54]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 46.5
# black 62.5
# brown 68.0
# [7, 34, 53]  sorted and before pop
# [7, 34, 53]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 51.5
# black 62.0
# brown 68.0
# [6, 33, 52]  sorted and before pop
# [6, 33, 52]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 36.0
# black 68.5
# brown 64.0
# [4, 31, 49]  sorted and before pop
# [4, 31, 49]  sorted and after pop
# Colors:  Brown Black  *  Orange
# list reset
# output: 10.0k
# (1080, 1920, 3)
# orange 47.5
# black 74.0
# brown 65.5
# [3, 30, 48]  sorted and before pop
# [3, 30, 48]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 49.0
# black 64.0
# brown 63.5
# [5, 32, 51]  sorted and before pop
# [5, 32, 51]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# orange 38.5
# black 67.0
# brown 68.0
# [7, 34, 53]  sorted and before pop
# [7, 34, 53]  sorted and after pop
# Colors:  Brown Black  *  Orange
# output: 10.0k
# (1080, 1920, 3)
# green 0.0
# green 0.0
# black 54.5
# [22]  sorted and before pop
# [22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# orange 194.0
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [8, 22]  sorted and before pop
# [8, 22]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 56.5
# red 40.0
# [8, 22, 58, 78]  sorted and before pop
# reached if pop
# popped:  22
# [8, 58, 78]  sorted and after pop
# Colors:  Orange Red  *  Red
# output: 3.2k
# (1080, 1920, 3)
# red 39.5
# red 37.0
# orange 36.0
# 0.0  lila
# 0.0  lila
# 0.0  lila
# [45, 65, 82]  sorted and before pop
# [45, 65, 82]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# 5.5  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# 0.0  lila
# 0.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# 2.0  lila
# 2.5  lila
# 0.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 39.0
# 2.0  lila
# 4.5  lila
# [31]  sorted and before pop
# [31]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 46.0
# red 48.0
# orange 50.0
# 9.0  lila
# [26, 31, 46, 64]  sorted and before pop
# reached if pop
# popped:  31
# [26, 46, 64]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 46.5
# red 44.0
# orange 57.5
# 12.0  lila
# [22, 43, 61]  sorted and before pop
# [22, 43, 61]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 32.5
# red 43.0
# orange 55.5
# 17.0  lila
# [22, 42, 60]  sorted and before pop
# [22, 42, 60]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 43.0
# red 37.5
# [26, 46]  sorted and before pop
# [26, 46]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 34.0
# red 40.0
# orange 49.5
# 14.0  lila
# [26, 29, 46, 49, 67]  sorted and before pop
# reached if pop
# popped:  29
# reached if pop
# popped:  49
# [26, 46, 67]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 32.0
# 0.0  lila
# [33]  sorted and before pop
# [33]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# [33]  sorted and before pop
# [33]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 32.0
# [30, 33]  sorted and before pop
# [30, 33]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 40.0
# 0.0  lila
# 0.0  lila
# [30, 31, 33]  sorted and before pop
# [30, 31, 33]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# red 34.0
# orange 44.5
# 9.0  lila
# [33, 70]  sorted and before pop
# [33, 70]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 52.5
# 26.5  lila
# [33, 35, 70]  sorted and before pop
# [33, 35, 70]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 48.0
# 14.5  lila
# [35]  sorted and before pop
# [35]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 37.5
# orange 55.5
# 29.0  lila
# [34, 35, 72]  sorted and before pop
# [34, 35, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 44.0
# orange 48.0
# 34.0  lila
# [34, 56, 72]  sorted and before pop
# [34, 56, 72]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# red 35.0
# red 48.0
# orange 58.5
# 19.5  lila
# [35, 56, 72]  sorted and before pop
# [35, 56, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# list reset
# output: 22.0k
# (1080, 1920, 3)
# red 58.5
# red 42.5
# 2.0  lila
# 0.0  lila
# [35, 56]  sorted and before pop
# [35, 56]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 50.5
# red 45.0
# orange 67.5
# 6.0  lila
# [35, 36, 56, 75]  sorted and before pop
# reached if pop
# popped:  36
# [35, 56, 75]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 61.0
# red 44.0
# orange 36.0
# 0.0  lila
# [37, 58, 76]  sorted and before pop
# [37, 58, 76]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 52.0
# red 45.0
# orange 32.0
# 0.0  lila
# [37, 58, 76]  sorted and before pop
# [37, 58, 76]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 49.0
# red 45.0
# orange 50.5
# 16.0  lila
# [40, 62, 79]  sorted and before pop
# [40, 62, 79]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 38.5
# red 48.0
# orange 58.5
# 0.0  lila
# 0.0  lila
# 19.0  lila
# [39, 64, 76]  sorted and before pop
# [39, 64, 76]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 69.0
# red 49.0
# orange 61.0
# 0.0  lila
# 0.0  lila
# 0.0  lila
# [39, 60, 77]  sorted and before pop
# [39, 60, 77]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 43.5
# red 42.5
# orange 57.5
# 0.0  lila
# 0.0  lila
# 23.5  lila
# [40, 63, 77]  sorted and before pop
# [40, 63, 77]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 45.5
# orange 39.0
# 22.0  lila
# [37, 76]  sorted and before pop
# [37, 76]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 35.0
# red 44.0
# orange 59.0
# 12.0  lila
# [35, 37, 56, 72, 76]  sorted and before pop
# reached if pop
# popped:  37
# reached if pop
# popped:  72
# [35, 56, 76]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 40.0
# orange 65.0
# 14.5  lila
# [36, 75]  sorted and before pop
# [36, 75]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 48.5
# red 48.0
# orange 31.5
# 0.0  lila
# [35, 36, 55, 75]  sorted and before pop
# reached if pop
# popped:  36
# [35, 55, 75]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 36.0
# orange 60.0
# 13.5  lila
# [38, 76]  sorted and before pop
# [38, 76]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 43.5
# red 45.0
# orange 48.0
# 15.5  lila
# [37, 38, 57, 76]  sorted and before pop
# reached if pop
# popped:  38
# [37, 57, 76]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 62.5
# red 39.5
# orange 58.5
# 0.0  lila
# [35, 56, 73]  sorted and before pop
# [35, 56, 73]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 37.5
# red 45.0
# orange 52.0
# 13.5  lila
# [34, 55, 72]  sorted and before pop
# [34, 55, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 44.0
# orange 40.5
# 14.0  lila
# [31, 69]  sorted and before pop
# [31, 69]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 60.0
# red 45.0
# orange 43.0
# [30, 31, 51, 69]  sorted and before pop
# reached if pop
# popped:  31
# [30, 51, 69]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 69.5
# red 45.0
# orange 48.0
# [29, 50, 69]  sorted and before pop
# [29, 50, 69]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 40.0
# orange 36.5
# 29.0  lila
# [31, 69]  sorted and before pop
# [31, 69]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 48.0
# orange 45.5
# 36.0  lila
# [31, 52, 69]  sorted and before pop
# [31, 52, 69]  sorted and after pop
# Colors:  Red Violet  *  Orange
# output: 27.0k
# (1080, 1920, 3)
# red 47.0
# red 40.0
# orange 36.0
# 8.0  lila
# [31, 51, 69]  sorted and before pop
# [31, 51, 69]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 59.5
# red 48.0
# orange 35.0
# 0.0  lila
# [31, 51, 69]  sorted and before pop
# [31, 51, 69]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 45.5
# orange 37.0
# 27.5  lila
# [32, 71]  sorted and before pop
# [32, 71]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 43.0
# orange 44.5
# 25.0  lila
# [32, 70, 71]  sorted and before pop
# [32, 70, 71]  sorted and after pop
# Colors:  Red Orange  *  Orange
# output: 23.0k
# (1080, 1920, 3)
# red 60.0
# red 45.0
# 14.0  lila
# [31, 52]  sorted and before pop
# [31, 52]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 45.0
# red 43.0
# 0.0  lila
# 6.0  lila
# [31, 52]  sorted and before pop
# [31, 52]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 30.5
# red 45.5
# 12.0  lila
# [30, 31, 51, 52]  sorted and before pop
# reached if pop
# popped:  31
# [30, 51, 52]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# red 56.0
# red 43.0
# 0.0  lila
# [28, 48]  sorted and before pop
# [28, 48]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 61.5
# red 37.5
# orange 30.5
# 6.0  lila
# [27, 28, 47, 48, 65]  sorted and before pop
# reached if pop
# popped:  28
# reached if pop
# popped:  48
# [27, 47, 65]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 66.0
# red 53.0
# 6.0  lila
# [27, 48]  sorted and before pop
# [27, 48]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 50.5
# red 53.0
# orange 31.5
# 6.0  lila
# [27, 48, 49, 66]  sorted and before pop
# reached if pop
# popped:  48
# [27, 49, 66]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 50.5
# red 52.0
# orange 40.0
# 6.0  lila
# [27, 48, 65]  sorted and before pop
# [27, 48, 65]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 31.0
# red 40.0
# 18.0  lila
# [27, 47]  sorted and before pop
# [27, 47]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 40.0
# orange 31.0
# [26, 27, 47, 64]  sorted and before pop
# reached if pop
# popped:  27
# [26, 47, 64]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 45.0
# [25]  sorted and before pop
# [25]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 45.5
# 20.5  lila
# [23, 25]  sorted and before pop
# [23, 25]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 37.0
# 16.5  lila
# [23, 25]  sorted and before pop
# [23, 25]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 42.5
# 0.0  lila
# 3.0  lila
# [20, 23, 25]  sorted and before pop
# [20, 23, 25]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# 4.5  lila
# 0.0  lila
# 3.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 36.0
# 0.0  lila
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# 0.0  lila
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 36.0
# 0.0  lila
# [20]  sorted and before pop
# [20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 40.0
# 5.5  lila
# 0.0  lila
# [19, 20]  sorted and before pop
# [19, 20]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 44.0
# 8.0  lila
# 0.0  lila
# [18, 19, 20]  sorted and before pop
# [18, 19, 20]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# red 40.0
# 0.0  lila
# [18]  sorted and before pop
# [18]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 42.0
# red 45.5
# [18, 27, 48]  sorted and before pop
# [18, 27, 48]  sorted and after pop
# Colors:  Red Red  *  Red
# output: 2.2k
# (1080, 1920, 3)
# 5.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# list reset
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 17.5  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# 0.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 106.5
# red 59.0
# orange 60.5
# 0.0  lila
# [30, 54, 78]  sorted and before pop
# [30, 54, 78]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 60.0
# [32]  sorted and before pop
# [32]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 92.5
# red 67.0
# orange 53.0
# 0.0  lila
# [29, 32, 56, 82]  sorted and before pop
# reached if pop
# popped:  32
# [29, 56, 82]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 88.0
# orange 33.5
# [24, 81]  sorted and before pop
# [24, 81]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# red 81.5
# red 80.0
# orange 82.0
# 2.0  lila
# [22, 24, 49, 73, 81]  sorted and before pop
# reached if pop
# popped:  24
# reached if pop
# popped:  73
# [22, 49, 81]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 105.5
# red 72.0
# orange 73.0
# [22, 48, 74]  sorted and before pop
# [22, 48, 74]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 99.0
# red 71.5
# orange 94.0
# 0.0  lila
# [18, 46, 71]  sorted and before pop
# [18, 46, 71]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 100.5
# red 76.0
# orange 72.0
# [18, 45, 72]  sorted and before pop
# [18, 45, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 92.5
# red 76.0
# orange 79.0
# [18, 47, 71]  sorted and before pop
# [18, 47, 71]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 103.0
# red 68.0
# orange 82.0
# 0.0  lila
# [21, 48, 72]  sorted and before pop
# [21, 48, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 111.0
# red 78.5
# orange 82.0
# 0.0  lila
# [21, 48, 74]  sorted and before pop
# [21, 48, 74]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 102.0
# red 67.5
# orange 74.0
# 0.0  lila
# [22, 48, 72]  sorted and before pop
# [22, 48, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 90.0
# red 76.0
# orange 82.5
# [21, 48, 73]  sorted and before pop
# [21, 48, 73]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 102.0
# red 80.0
# orange 82.5
# 0.0  lila
# [21, 48, 72]  sorted and before pop
# [21, 48, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 96.0
# red 72.0
# orange 88.0
# 0.0  lila
# [21, 48, 72]  sorted and before pop
# [21, 48, 72]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 80.0
# red 72.0
# orange 87.0
# [19, 48, 71]  sorted and before pop
# [19, 48, 71]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# red 89.5
# red 67.5
# orange 77.0
# 6.0  lila
# [22, 48, 73]  sorted and before pop
# [22, 48, 73]  sorted and after pop
# Colors:  Red Red  *  Orange
# output: 22.0k
# (1080, 1920, 3)
# 12.5  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 16.0
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 22.0
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 32.0
# green 32.0
# 3.0  lila
# black 37.0
# [22, 44]  sorted and before pop
# [22, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 24.0
# 0.0  lila
# 0.0  lila
# [22, 44]  sorted and before pop
# [22, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 15.0
# 0.0  lila
# [22, 44]  sorted and before pop
# [22, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 28.0
# black 37.5
# brown 80.0
# [17, 22, 44, 54]  sorted and before pop
# reached if pop
# popped:  22
# [17, 44, 54]  sorted and after pop
# Colors:  Brown Green  *  Black
# output: 15
# (1080, 1920, 3)
# green 45.5
# green 45.5
# [76]  sorted and before pop
# [76]  sorted and after pop
# reached if
# list reset
# output: 0
# (1080, 1920, 3)
# green 0.0
# green 12.0
# black 32.5
# [52, 76]  sorted and before pop
# [52, 76]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 8.5
# green 0.0
# black 33.0
# [50, 52, 76]  sorted and before pop
# [50, 52, 76]  sorted and after pop
# Colors:  Black Black  *  Green
# output: 0
# (1080, 1920, 3)
# green 11.0
# black 33.0
# [50]  sorted and before pop
# [50]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 4.0
# black 30.5
# [47, 50]  sorted and before pop
# [47, 50]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# [47, 50]  sorted and before pop
# [47, 50]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# [47, 50]  sorted and before pop
# [47, 50]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# black 34.5
# brown 89.5
# dark brown
# [10, 46, 47, 48, 50]  sorted and before pop
# reached if pop
# popped:  46
# reached if pop
# popped:  48
# [10, 47, 50]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# black 33.5
# dark brown
# [45, 48]  sorted and before pop
# [45, 48]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# black 35.0
# [44, 45, 48]  sorted and before pop
# [44, 45, 48]  sorted and after pop
# Colors:  Black Black  *  Brown
# output: 0
# (1080, 1920, 3)
# green 0.0
# black 36.0
# brown 36.0
# [7, 44]  sorted and before pop
# [7, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 45.5
# [4, 7, 44]  sorted and before pop
# [4, 7, 44]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# green 0.0
# black 32.0
# brown 46.0
# [4, 42]  sorted and before pop
# [4, 42]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 12.0
# brown 46.0
# dark brown
# [4, 42, 43]  sorted and before pop
# [4, 42, 43]  sorted and after pop
# Colors:  Brown Black  *  Brown
# output: 100
# (1080, 1920, 3)
# 0.0  lila
# dark brown
# [39]  sorted and before pop
# [39]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 40.0
# green 40.0
# [39, 61]  sorted and before pop
# [39, 61]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 31.0
# green 31.0
# [39, 61, 63]  sorted and before pop
# [39, 61, 63]  sorted and after pop
# Colors:  Brown Green  *  Green
# output: 1.5M
# (1080, 1920, 3)
# green 16.0
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 63.0
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [41]  sorted and before pop
# [41]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 32.0
# dark brown
# [10, 41, 50]  sorted and before pop
# [10, 41, 50]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# green 0.0
# brown 71.5
# dark brown
# [4, 44]  sorted and before pop
# [4, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# [4, 44]  sorted and before pop
# [4, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 17.0
# brown 73.5
# [4, 11, 44]  sorted and before pop
# [4, 11, 44]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# green 0.0
# brown 75.5
# [13]  sorted and before pop
# [13]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 75.0
# [13, 15]  sorted and before pop
# [13, 15]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 76.5
# [13, 15, 17]  sorted and before pop
# [13, 15, 17]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# green 0.0
# brown 80.5
# [25]  sorted and before pop
# [25]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 91.0
# [25, 26]  sorted and before pop
# [25, 26]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 77.0
# [25, 26, 29]  sorted and before pop
# [25, 26, 29]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# brown 70.0
# [29]  sorted and before pop
# [29]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 31.0
# green 31.0
# [29, 92]  sorted and before pop
# [29, 92]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 18.5
# [29, 92]  sorted and before pop
# [29, 92]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [29, 92]  sorted and before pop
# [29, 92]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 17.5
# [29, 92]  sorted and before pop
# [29, 92]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# [29, 92]  sorted and before pop
# [29, 92]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 7.0
# brown 72.0
# [27, 29, 92]  sorted and before pop
# [27, 29, 92]  sorted and after pop
# Colors:  Brown Brown  *  Green
# output: 1.1M
# (1080, 1920, 3)
# 2.5  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 10.0
# 6.5  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 15.5
# black 33.0
# brown 73.0
# [30, 64]  sorted and before pop
# [30, 64]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 24.0
# brown 72.0
# [30, 34, 64]  sorted and before pop
# [30, 34, 64]  sorted and after pop
# Colors:  Brown Brown  *  Black
# list reset
# output: 11
# (1080, 1920, 3)
# green 1.0
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 43.0
# [37]  sorted and before pop
# [37]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 8.0
# [37]  sorted and before pop
# [37]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# [37]  sorted and before pop
# [37]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 8.5
# [37]  sorted and before pop
# [37]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 32.0
# [21, 37]  sorted and before pop
# [21, 37]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 41.5
# dark brown
# [19, 21, 37, 60]  sorted and before pop
# reached if pop
# popped:  21
# [19, 37, 60]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# green 0.0
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 80.0
# [17]  sorted and before pop
# [17]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 78.5
# [17]  sorted and before pop
# [17]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 86.0
# [15, 17]  sorted and before pop
# [15, 17]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 1.5
# brown 71.0
# [15, 17, 18]  sorted and before pop
# [15, 17, 18]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# green 20.0
# brown 85.5
# [14]  sorted and before pop
# [14]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 75.0
# [10, 14]  sorted and before pop
# [10, 14]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 49.5
# [6, 10, 14]  sorted and before pop
# [6, 10, 14]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# green 0.0
# brown 86.5
# dark brown
# [3, 44]  sorted and before pop
# [3, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 32.0
# [2, 3, 44]  sorted and before pop
# [2, 3, 44]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# dark brown
# [38]  sorted and before pop
# [38]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [38]  sorted and before pop
# [38]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [38]  sorted and before pop
# [38]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 92.0
# [0, 38]  sorted and before pop
# [0, 38]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 96.0
# [0, 2, 38]  sorted and before pop
# [0, 2, 38]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# brown 57.0
# dark brown
# [5, 48]  sorted and before pop
# [5, 48]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 88.5
# [5, 12, 48]  sorted and before pop
# [5, 12, 48]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# brown 88.0
# [17]  sorted and before pop
# [17]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 108.0
# [14, 17]  sorted and before pop
# [14, 17]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [14, 17]  sorted and before pop
# [14, 17]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [14, 17]  sorted and before pop
# [14, 17]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [14, 17]  sorted and before pop
# [14, 17]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# brown 100.0
# dark brown
# [14, 17, 53]  sorted and before pop
# [14, 17, 53]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# brown 100.0
# dark brown
# [19, 60]  sorted and before pop
# [19, 60]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# brown 71.5
# [19, 26, 60]  sorted and before pop
# [19, 26, 60]  sorted and after pop
# Colors:  Brown Brown  *  Brown
# output: 110
# (1080, 1920, 3)
# green 0.0
# black 36.0
# brown 90.0
# [32, 70]  sorted and before pop
# [32, 70]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 32.0
# green 32.0
# black 36.0
# brown 82.5
# [32, 68, 70, 91]  sorted and before pop
# reached if pop
# popped:  68
# [32, 70, 91]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 30.0
# black 44.0
# brown 88.0
# dark brown
# [20, 23, 54]  sorted and before pop
# [20, 23, 54]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# green 48.0
# green 48.0
# black 52.0
# brown 80.0
# [13, 47, 68]  sorted and before pop
# [13, 47, 68]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 48.0
# green 48.0
# black 44.0
# brown 76.0
# [24, 57, 77]  sorted and before pop
# [24, 57, 77]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 32.0
# green 32.0
# black 39.0
# brown 54.0
# [30, 62, 83]  sorted and before pop
# [30, 62, 83]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 36.0
# green 36.0
# black 45.0
# [62, 82]  sorted and before pop
# [62, 82]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 41.0
# green 41.0
# black 49.5
# brown 72.0
# [31, 62, 63, 82, 83]  sorted and before pop
# reached if pop
# popped:  62
# reached if pop
# popped:  82
# [31, 63, 83]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 40.5
# green 40.5
# black 39.0
# brown 73.0
# [27, 60, 79]  sorted and before pop
# [27, 60, 79]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 20.5
# black 48.0
# brown 75.0
# [23, 55]  sorted and before pop
# [23, 55]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# green 0.0
# black 45.0
# brown 75.0
# [22, 23, 54, 55]  sorted and before pop
# reached if pop
# popped:  23
# [22, 54, 55]  sorted and after pop
# Colors:  Brown Black  *  Black
# list reset
# output: 10
# (1080, 1920, 3)
# green 11.0
# green 0.0
# black 42.5
# brown 79.0
# [22, 55]  sorted and before pop
# [22, 55]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 34.0
# green 34.0
# black 37.5
# [22, 55, 76]  sorted and before pop
# [22, 55, 76]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 30.0
# black 40.0
# [54]  sorted and before pop
# [54]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 24.0
# black 40.0
# brown 51.5
# [21, 54]  sorted and before pop
# [21, 54]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 28.0
# black 44.0
# brown 55.0
# [19, 21, 51, 54]  sorted and before pop
# reached if pop
# popped:  21
# [19, 51, 54]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# green 25.0
# black 48.0
# brown 54.0
# [19, 51]  sorted and before pop
# [19, 51]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 23.5
# black 40.0
# brown 49.0
# [19, 20, 51, 52]  sorted and before pop
# reached if pop
# popped:  20
# [19, 51, 52]  sorted and after pop
# Colors:  Brown Black  *  Black
# output: 10
# (1080, 1920, 3)
# green 22.5
# black 40.0
# brown 44.5
# [19, 52]  sorted and before pop
# [19, 52]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 41.0
# green 41.0
# black 43.0
# brown 59.5
# [19, 26, 52, 57, 77]  sorted and before pop
# reached if pop
# popped:  26
# reached if pop
# popped:  57
# [19, 52, 77]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 19.0
# black 56.0
# brown 35.5
# [22, 52]  sorted and before pop
# [22, 52]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 38.0
# green 38.0
# green 0.0
# black 56.0
# brown 40.5
# [22, 30, 52, 60, 80]  sorted and before pop
# reached if pop
# popped:  30
# reached if pop
# popped:  60
# [22, 52, 80]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 40.0
# green 40.0
# black 53.0
# brown 54.0
# [31, 60, 81]  sorted and before pop
# [31, 60, 81]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 36.0
# green 36.0
# green 0.0
# black 54.0
# brown 63.5
# [32, 62, 82]  sorted and before pop
# [32, 62, 82]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 40.0
# green 40.0
# black 50.5
# brown 60.0
# [31, 61, 81]  sorted and before pop
# [31, 61, 81]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 46.0
# green 46.0
# black 48.0
# brown 58.0
# [31, 62, 81]  sorted and before pop
# [31, 62, 81]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 45.5
# green 45.5
# green 0.0
# black 56.0
# brown 66.5
# [30, 60, 80]  sorted and before pop
# [30, 60, 80]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 31.0
# green 31.0
# black 49.0
# brown 64.0
# [29, 59, 79]  sorted and before pop
# [29, 59, 79]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 32.0
# green 32.0
# black 44.0
# brown 56.0
# [29, 59, 79]  sorted and before pop
# [29, 59, 79]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 31.0
# green 31.0
# black 43.0
# brown 57.0
# [29, 59, 79]  sorted and before pop
# [29, 59, 79]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 38.0
# green 38.0
# green 3.0
# black 54.5
# brown 64.0
# [26, 56, 76]  sorted and before pop
# [26, 56, 76]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 0.0
# green 30.5
# green 30.5
# black 47.5
# brown 59.5
# [23, 53, 73]  sorted and before pop
# [23, 53, 73]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 36.0
# green 36.0
# black 52.0
# brown 58.5
# [20, 50, 70]  sorted and before pop
# [20, 50, 70]  sorted and after pop
# Colors:  Brown Black  *  Green
# output: 1.0M
# (1080, 1920, 3)
# green 24.5
# black 37.5
# brown 57.0
# [12, 44]  sorted and before pop
# [12, 44]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# green 0.0
# green 0.0
# 0.0  lila
# brown 32.5
# [12, 27, 44]  sorted and before pop
# [12, 27, 44]  sorted and after pop
# Colors:  Brown Brown  *  Black
# output: 11
# (1080, 1920, 3)
# 0.0  lila
# 0.0  lila
# 7.5  lila
# 0.0  lila
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# []  sorted and before pop
# []  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 792.0
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# black 792.0
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# [0]  sorted and before pop
# [0]  sorted and after pop
# reached if
# output: 0
# (1080, 1920, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-9d8b787b18d8> in <module>
#     425
#     426
# --> 427 cap.release()
#     428 cv2.destroyAllWindows()
#     429 cv2.waitKey(1)
#
# NameError: name 'cap' is not defined

# %%
test = ['0', '2.0M', '12', '0', '12', '1.0M', '21', '1.0M', '12', '21', '12', '12', '12', 
        '1.0M', '2.0M', '1.0M', '0', '1.0M', '2.0M', '1.0M', 
         '200.0k', '1.0M', '2.0M', '1.0M', 
        '1.0M', '12', '12', '21', '1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '2.0M', 
        '1.0M', '2.0M', '1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '12', '1.0M', '2.0M', '0',  
         '1.0M','10', '1.0M', '0', '0', '0', 
        '0', '700.0k', '1.0M', '1.0M', '1.0M', '0', '0', '0', '10', '0', '0', '0', '0', '0', 
        '10', '700.0k', '11', '1.0M', '0', '0', '1.0M', '0', '1.0M', '0', '0', '0', '0', '0', 
        ]
test_max = max(test, key=test.count)
print(test_max)
# Out:
# 1.0M
