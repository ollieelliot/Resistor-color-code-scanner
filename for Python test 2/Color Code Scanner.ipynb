# %%
# %matplotlib auto
import numpy as np
import cv2
from keras.preprocessing.image import ImageDataGenerator

from skimage import io
import os
from skimage.filters import threshold_yen
from skimage.exposure import rescale_intensity
from skimage.io import imread, imsave
from matplotlib import pyplot as plt 

from PIL import Image
import imutils
# Out:
# Using matplotlib backend: Qt5Agg

# %%
import requests
address = 'http://192.168.0.30:8080/shot.jpg'
colors = {}
#input = "/Users/oliver/Downloads/resistor_photo.jpeg"

color_bands = {"Black": 0, "Brown": 1, "Red": 2, "Orange": 3, "Yellow": 4, "Green": 5, "Blue": 6, "Violet": 7, "Grey": 8, "White": 9}
color_multipliers = {"Black": 1, "Brown": 10, "Red": 100, "Orange": 1000, "Yellow": 10000, "Green": 100000, "Blue":1000000 , "Violet": 10000000, "Grey": 100000000, "White": 100000000}


temp_start = (900, 530)
temp_end = (1100, 550)


while True:

    
    img_resp = requests.get(address)
    img_arr = np.array(bytearray(img_resp.content), dtype=np.uint8)
    frame = cv2.imdecode(img_arr, -1)
    #frame = cv2.imread(input)
    height, width, channels = frame.shape
    #start = (int(width/2 - 50), int(height/2))
    #end = (int(width/2 + 50),int(height/2) + 30)
    show_frame = frame
    
    cv2.bilateralFilter(frame, 5, 80, 80)
    
    cv2.rectangle(frame, temp_start, temp_end, (255,255,255), 1)
    
    frame = frame[530:550, 550+350:800+300]
    
   
    
    

    #frame = cv2.imread('roi.jpg')
    
  
    #_, frame = cap.read()
    #frame = cv2.resize(frame, (height*4,width*4), interpolation = cv2.INTER_LINEAR_EXACT)
    
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)


    lower_blue = np.array([80, 50, 50]) #lower boundry
    upper_blue = np.array([106, 250, 150]) #upper boundry
    
    lower_green = np.array([34, 43, 54]) #lower boundry, original 40,70,80
    upper_green = np.array([179, 255, 255]) #upper boundry, original 70, 255, 255
    
    lower_red = np.array([0, 136, 122]) 
    upper_red = np.array([179, 181, 176]) 
    
    lower_yellow = np.array([19, 88, 72]) #lower boundry
    upper_yellow = np.array([179, 255, 255]) #upper boundry
    
    lower_orange = np.array([0, 102, 136]) #5, 190, 200
    upper_orange = np.array([12, 255, 255]) #18, 225, 255
    
    lower_violet = np.array([[130, 40, 50]])
    upper_violet = np.array([155, 250, 150])
    
    lower_black = np.array([[0, 0, 0]])
    upper_black = np.array([180, 250, 70])
    
    lower_brown = np.array([[0, 68, 79]]) #0,100,0
    upper_brown = np.array([12, 236, 135]) #12,255,121
    
    lower_brown_light = np.array([[4, 109, 138]])
    upper_brown_light = np.array([11, 255, 233])
    
    lower_black_light = np.array([[0, 0, 0]])
    upper_black_light = np.array([179, 255, 14])
    
    lower_violet_dark = np.array([[92, 74, 0]])
    upper_violet_dark = np.array([174, 255, 255])
    
    lower_red_dark = np.array([171, 65, 50]) 
    upper_red_dark = np.array([180, 250, 150]) 
    
    

    mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)
    mask_red = cv2.inRange(hsv, lower_red, upper_red)
    mask_yellow = cv2.inRange(hsv, lower_yellow, upper_yellow)
    mask_orange = cv2.inRange(hsv, lower_orange, upper_orange)
    mask_violet = cv2.inRange(hsv, lower_violet, upper_violet)
    mask_black = cv2.inRange(hsv, lower_black, upper_black)
    mask_brown = cv2.inRange(hsv, lower_brown, upper_brown)
    mask_brown_light = cv2.inRange(hsv, lower_brown_light, upper_brown_light)
    mask_black_light = cv2.inRange(hsv, lower_black_light, upper_black_light)
    mask_violet_dark = cv2.inRange(hsv, lower_violet_dark, upper_violet_dark)
    mask_red_dark = cv2.inRange(hsv, lower_red_dark, upper_red_dark)
    
    contour1 = cv2.findContours(mask_blue, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour1 = imutils.grab_contours(contour1)
    
    contour2 = cv2.findContours(mask_green, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour2 = imutils.grab_contours(contour2)
    
    contour3 = cv2.findContours(mask_red, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour3 = imutils.grab_contours(contour3)
    
    contour4 = cv2.findContours(mask_yellow, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour4 = imutils.grab_contours(contour4)
    
    contour5 = cv2.findContours(mask_orange, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour5 = imutils.grab_contours(contour5)
    
    contour6 = cv2.findContours(mask_violet, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour6 = imutils.grab_contours(contour6)
    
    contour7 = cv2.findContours(mask_black, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour7 = imutils.grab_contours(contour7)
    
    contour8 = cv2.findContours(mask_brown, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour8 = imutils.grab_contours(contour8)
    
    contour9 = cv2.findContours(mask_brown_light, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour9 = imutils.grab_contours(contour9)
    
    contour10 = cv2.findContours(mask_black_light, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour10 = imutils.grab_contours(contour10)
    
    contour11 = cv2.findContours(mask_violet_dark, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour11 = imutils.grab_contours(contour11)
    
    contour12 = cv2.findContours(mask_red_dark, cv2.RETR_TREE, cv2.CHAIN_APPROX_TC89_L1)
    contour12 = imutils.grab_contours(contour12)
    
    area_limit = 50
    for c in contour1:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("blue", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            x1,y1,w1,h1 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x1,y1),(x1+w1,y1+h1),(255,255,0),1)
            cv2.putText(frame, "Blue", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
            
            if x1 not in colors:
                colors[x1] = 'Blue'
                
            
    for c in contour2:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("green", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            # Find bounding rectangles
            x2,y2,w2,h2 = cv2.boundingRect(c)
            # Draw the rectangle
            cv2.rectangle(frame,(x2,y2),(x2+w2,y2+h2),(255,255,0),1)
            cv2.putText(frame, "Green", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)
            
            if x2 not in colors:
                colors[x2] = 'Green'
    
    for c in contour3:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("red", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            x3,y3,w3,h3 = cv2.boundingRect(c)
            
            cv2.rectangle(frame,(x3,y3),(x3+w3,y3+h3),(255,255,0),1)
            
            cv2.putText(frame, "Red", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
            
            if x3 not in colors:
                colors[x3] = 'Red'
    
    for c in contour4:
        
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("yellow", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            x4,y4,w4,h4 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x4,y4),(x4+w4,y4+h4),(255,255,0),1)
            
            cv2.putText(frame, "Yellow", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 3)
            
            if x4 not in colors:
                colors[x4] = 'Yellow'

    for c in contour5:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("orange", area)
            
            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x5,y5,w5,h5 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x5,y5),(x5+w5,y5+h5),(255,255,0),1)
            cv2.putText(frame, "Orange", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (2, 106, 255), 3)
            
            if x5 not in colors:
                colors[x5] = 'Orange'

    
    for c in contour6:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("violet", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x6,y6,w6,h6 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x6,y6),(x6+w6,y6+h6),(255,255,0),1)
            cv2.putText(frame, "Violet", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (238, 130, 238), 3)
            
            if x6 not in colors:
                colors[x6] = 'Violet'


    for c in contour7:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("black", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x7,y7,w7,h7 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x7,y7),(x7+w7,y7+h7),(255,255,0),1)
            cv2.putText(frame, "Black", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (50, 0, 0), 3)
            
            if x7 not in colors:
                colors[x7] = 'Black'

    
    for c in contour8:
        area = cv2.contourArea(c)
        if area > area_limit:
            print("brown", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x8,y8,w8,h8 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x8,y8),(x8+w8,y8+h8),(255,255,0),1)
            cv2.putText(frame, "Brown", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (42, 42, 165), 3)
            
            if x8 not in colors:
                colors[x8] = 'Brown'

    
    for c in contour9:
        area = cv2.contourArea(c)
        if area > area_limit:
            #print("brown light", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x9,y9,w9,h9 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x9,y9),(x9+w9,y9+h9),(255,255,0),1)
            cv2.putText(frame, "Brown", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (42, 42, 165), 3)
            
            if x9 not in colors:
                colors[x9] = 'Brown'

    
    for c in contour10:
        area = cv2.contourArea(c)
        #print("black", area)
        if area > area_limit:
            
            #print("black light", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x10,y10,w10,h10 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x10,y10),(x10+w10,y10+h10),(255,255,0),1)
            cv2.putText(frame, "Black", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 50), 3)
            
            if x10 not in colors:
                colors[x10] = 'Black'

    for c in contour11:
        area = cv2.contourArea(c)
        #if area > 500:
            #print(area)
        if area > area_limit:
            
            #print("violet dark", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)

            x11,y11,w11,h11 = cv2.boundingRect(c)
            cv2.rectangle(frame,(x11,y11),(x11+w11,y11+h11),(255,255,0),1)
            cv2.putText(frame, "Violet", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (238, 130, 238), 3)
            
            if x11 not in colors:
                colors[x11] = 'Violet'
                
    for c in contour12:
        area = cv2.contourArea(c)
        #print("red dark", area)
        if area > area_limit:
            print("red dark", area)

            #cv2.drawContours(frame,[c],-1,(0,255,0), 3)

            M = cv2.moments(c)

            cx = int(M["m10"]/ M["m00"])
            cy = int(M["m01"]/ M["m00"])

            #cv2.circle(frame,(cx,cy),7,(255,255,255),-1)
            
            x12,y12,w12,h12 = cv2.boundingRect(c)
            
            cv2.rectangle(frame,(x12,y12),(x12+w12,y12+h12),(255,255,0),1)
            
            cv2.putText(frame, "Red", (cx-20, cy-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
            
            if x12 not in colors:
                colors[x12] = 'Red'
        
    
    #Display ohm
    
    colors_list = []
    for color in colors.keys():
             colors_list.append(color)

    colors_list = sorted(colors_list)

    print(colors_list)
    
    if len(colors_list) <3:
        print("reached if")
        color1 = "Black"
        color2 = "Black"
        color3 = "Black"
        
        
                
    else:
        color1 = colors[colors_list[0]]
        color2 = colors[colors_list[1]]
        color3 = colors[colors_list[2]]
        print("Colors: ", color1, color2, " * ", color3)
        colors = {}
        
       
    #Fix: List builds up over time and never resets, new values every new frame won't be taken into account 
    #     and thus ignored
    
    #Fix: Imshow is only showing a new frame when a new object is detected (possibly because of putText? 
    #     Try/Catch around if/else above)
   

    combined = int(str(color_bands[color1]) + str(color_bands[color2]))

    ohms = str(combined*color_multipliers[color3])
    cv2.putText(show_frame,ohms + ' ohm',(0,int(height*0.9)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    print(show_frame.shape)
    cv2.imshow("result",show_frame)
    
    #Close window
    key = cv2.waitKey(1) 
    if key == 27:
        break
    
    
        
    print(ohms)
    print(colors)
    
        
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# black 3564.0
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# green 3564.0
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# brown 2411.0
# [1, 5]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black', 5: 'Brown'}
# black 3564.0
# [1, 5]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black', 5: 'Brown'}
# black 3564.0
# [1, 5]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black', 5: 'Brown'}
# brown 2938.0
# [1, 5]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black', 5: 'Brown'}
# black 3564.0
# [1, 5]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black', 5: 'Brown'}
# black 3564.0
# [1, 5]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black', 5: 'Brown'}
# brown 3150.5
# [1, 5]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black', 5: 'Brown'}
# black 75.0
# black 1430.5
# [1, 5, 12, 44]
# Colors:  Black Brown  *  Black
# (1080, 1920, 3)
# 1
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# black 3564.0
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# orange 98.0
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# orange 159.0
# orange 67.5
# orange 168.5
# [1, 79, 145]
# Colors:  Black Brown  *  Brown
# (1080, 1920, 3)
# 10
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# orange 217.5
# orange 223.0
# orange 252.5
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# [49, 109]
# reached if
# (1080, 1920, 3)
# 0
# {109: 'Brown', 49: 'Brown'}
# orange 223.5
# orange 241.0
# orange 169.5
# [49, 97, 109, 158]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 215.0
# [82]
# reached if
# (1080, 1920, 3)
# 0
# {82: 'Brown'}
# [82]
# reached if
# (1080, 1920, 3)
# 0
# {82: 'Brown'}
# [82]
# reached if
# (1080, 1920, 3)
# 0
# {82: 'Brown'}
# [82]
# reached if
# (1080, 1920, 3)
# 0
# {82: 'Brown'}
# orange 70.5
# [82]
# reached if
# (1080, 1920, 3)
# 0
# {82: 'Brown'}
# orange 190.0
# orange 260.5
# orange 243.0
# [31, 82, 94]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 57.5
# orange 168.5
# [38]
# reached if
# (1080, 1920, 3)
# 0
# {38: 'Brown'}
# orange 160.5
# [38, 41]
# reached if
# (1080, 1920, 3)
# 0
# {38: 'Brown', 41: 'Brown'}
# orange 71.5
# orange 104.0
# orange 174.0
# [38, 41]
# reached if
# (1080, 1920, 3)
# 0
# {38: 'Brown', 41: 'Brown'}
# orange 228.5
# orange 136.5
# orange 210.5
# [38, 41, 51, 112]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 160.0
# orange 164.5
# orange 145.5
# [90, 152]
# reached if
# (1080, 1920, 3)
# 0
# {152: 'Brown', 90: 'Brown'}
# orange 202.5
# orange 270.5
# orange 185.5
# [51, 90, 152]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 235.0
# orange 221.5
# orange 196.0
# [64, 126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown', 64: 'Brown'}
# orange 239.0
# orange 287.0
# orange 269.5
# [52, 64, 86, 116, 126]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 385.5
# orange 227.0
# [40, 155]
# reached if
# (1080, 1920, 3)
# 0
# {155: 'Yellow', 40: 'Brown'}
# [40, 155]
# reached if
# (1080, 1920, 3)
# 0
# {155: 'Yellow', 40: 'Brown'}
# [40, 155]
# reached if
# (1080, 1920, 3)
# 0
# {155: 'Yellow', 40: 'Brown'}
# black 3564.0
# [1, 40, 155]
# Colors:  Black Brown  *  Yellow
# (1080, 1920, 3)
# 10000
# {}
# black 773.0
# black 620.5
# [1, 46, 92, 107]
# Colors:  Black Black  *  Yellow
# (1080, 1920, 3)
# 0
# {}
# green 121.5
# green 558.5
# red 510.5
# orange 322.0
# black 2794.0
# brown 125.5
# [1, 6, 23, 41, 43, 89]
# Colors:  Red Brown  *  Brown
# (1080, 1920, 3)
# 210
# {}
# black 3179.5
# brown 336.5
# [1, 20]
# reached if
# (1080, 1920, 3)
# 0
# {20: 'Black', 1: 'Brown'}
# green 1638.0
# green 459.0
# black 161.5
# [1, 20, 27, 28, 108, 121, 173]
# Colors:  Brown Black  *  Green
# (1080, 1920, 3)
# 1000000
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# brown 50.5
# [23]
# reached if
# (1080, 1920, 3)
# 0
# {23: 'Brown'}
# [23]
# reached if
# (1080, 1920, 3)
# 0
# {23: 'Brown'}
# [23]
# reached if
# (1080, 1920, 3)
# 0
# {23: 'Brown'}
# [23]
# reached if
# (1080, 1920, 3)
# 0
# {23: 'Brown'}
# [23]
# reached if
# (1080, 1920, 3)
# 0
# {23: 'Brown'}
# [23]
# reached if
# (1080, 1920, 3)
# 0
# {23: 'Brown'}
# brown 52.0
# [23, 72]
# reached if
# (1080, 1920, 3)
# 0
# {23: 'Brown', 72: 'Brown'}
# orange 79.0
# orange 159.0
# [23, 72, 94]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 180.5
# orange 200.5
# orange 159.0
# [86]
# reached if
# (1080, 1920, 3)
# 0
# {86: 'Brown'}
# orange 204.0
# orange 143.5
# orange 196.5
# [18, 75, 86]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 184.5
# orange 216.0
# orange 196.5
# [19, 73]
# reached if
# (1080, 1920, 3)
# 0
# {73: 'Brown', 19: 'Brown'}
# orange 154.5
# orange 125.5
# orange 162.0
# [19, 73, 88]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 71.0
# brown 53.5
# [87, 114]
# reached if
# (1080, 1920, 3)
# 0
# {87: 'Brown', 114: 'Brown'}
# [87, 114]
# reached if
# (1080, 1920, 3)
# 0
# {87: 'Brown', 114: 'Brown'}
# [87, 114]
# reached if
# (1080, 1920, 3)
# 0
# {87: 'Brown', 114: 'Brown'}
# red 58.5
# orange 188.0
# orange 116.0
# orange 109.0
# [33, 80, 87, 114]
# Colors:  Red Brown  *  Brown
# (1080, 1920, 3)
# 210
# {}
# red 54.5
# orange 82.0
# orange 92.5
# orange 141.0
# [26, 73]
# reached if
# (1080, 1920, 3)
# 0
# {26: 'Red', 73: 'Brown'}
# red 56.5
# orange 56.0
# orange 52.0
# orange 151.0
# [26, 30, 73]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# green 56.0
# red 95.0
# red 89.5
# red 60.5
# orange 162.5
# orange 94.0
# orange 78.0
# [27, 54, 74, 77]
# Colors:  Red Green  *  Brown
# (1080, 1920, 3)
# 250
# {}
# orange 60.0
# orange 56.5
# orange 109.5
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# red 64.0
# red 52.5
# orange 145.5
# orange 127.0
# orange 133.5
# [29, 56, 77]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 54.0
# orange 60.0
# orange 95.0
# orange 129.0
# [29, 76, 157]
# Colors:  Red Brown  *  Yellow
# (1080, 1920, 3)
# 210000
# {}
# red 67.5
# orange 104.0
# orange 175.0
# orange 143.0
# [55, 75]
# reached if
# (1080, 1920, 3)
# 0
# {55: 'Red', 75: 'Brown'}
# red 63.5
# orange 199.0
# orange 143.5
# orange 170.0
# [55, 56, 75, 77]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 71.5
# orange 178.5
# orange 169.0
# orange 176.5
# [58, 80]
# reached if
# (1080, 1920, 3)
# 0
# {58: 'Red', 80: 'Brown'}
# green 73.0
# orange 180.0
# orange 140.5
# [58, 62, 63, 80, 87]
# Colors:  Red Green  *  Yellow
# (1080, 1920, 3)
# 250000
# {}
# orange 171.0
# orange 116.5
# orange 168.0
# [88]
# reached if
# (1080, 1920, 3)
# 0
# {88: 'Brown'}
# green 81.0
# orange 104.0
# orange 78.5
# red dark 65.0
# [66, 67, 88, 90]
# Colors:  Green Yellow  *  Brown
# (1080, 1920, 3)
# 540
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# green 51.0
# orange 50.5
# [60]
# reached if
# (1080, 1920, 3)
# 0
# {60: 'Green'}
# orange 80.5
# orange 54.5
# [60]
# reached if
# (1080, 1920, 3)
# 0
# {60: 'Green'}
# orange 87.5
# orange 89.5
# [60, 88]
# reached if
# (1080, 1920, 3)
# 0
# {60: 'Green', 88: 'Brown'}
# orange 132.0
# orange 136.5
# orange 122.5
# [60, 88]
# reached if
# (1080, 1920, 3)
# 0
# {60: 'Green', 88: 'Brown'}
# red 53.0
# orange 173.0
# orange 143.5
# orange 169.0
# [60, 65, 86, 88]
# Colors:  Green Red  *  Brown
# (1080, 1920, 3)
# 520
# {}
# orange 202.5
# orange 183.0
# orange 144.5
# [85]
# reached if
# (1080, 1920, 3)
# 0
# {85: 'Brown'}
# orange 161.0
# orange 165.5
# orange 138.0
# [84, 85]
# reached if
# (1080, 1920, 3)
# 0
# {85: 'Brown', 84: 'Brown'}
# orange 184.5
# orange 164.5
# orange 175.0
# [25, 80, 84, 85]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 190.5
# orange 170.5
# orange 171.5
# [21, 77]
# reached if
# (1080, 1920, 3)
# 0
# {77: 'Brown', 21: 'Brown'}
# orange 208.0
# orange 230.0
# orange 155.0
# [21, 75, 77]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# red 64.5
# orange 193.5
# orange 160.0
# orange 182.5
# [49, 70]
# reached if
# (1080, 1920, 3)
# 0
# {49: 'Red', 70: 'Brown'}
# red 57.0
# orange 188.0
# orange 225.0
# orange 181.0
# [15, 47, 49, 67, 70]
# Colors:  Brown Red  *  Red
# (1080, 1920, 3)
# 1200
# {}
# orange 210.0
# orange 173.5
# orange 155.5
# [68]
# reached if
# (1080, 1920, 3)
# 0
# {68: 'Brown'}
# red 61.0
# orange 189.5
# orange 190.0
# orange 169.0
# [48, 68, 70]
# Colors:  Red Brown  *  Brown
# (1080, 1920, 3)
# 210
# {}
# red 68.0
# orange 202.0
# orange 206.0
# orange 177.5
# [49, 70]
# reached if
# (1080, 1920, 3)
# 0
# {49: 'Red', 70: 'Brown'}
# red 74.5
# orange 218.0
# orange 204.0
# orange 202.5
# [49, 50, 70, 71]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 73.0
# orange 196.0
# orange 206.0
# orange 160.0
# [49, 70]
# reached if
# (1080, 1920, 3)
# 0
# {49: 'Red', 70: 'Brown'}
# orange 215.0
# orange 197.5
# orange 187.0
# [49, 70, 71]
# Colors:  Red Brown  *  Brown
# (1080, 1920, 3)
# 210
# {}
# red 50.5
# orange 225.5
# orange 139.5
# orange 173.5
# [50, 71]
# reached if
# (1080, 1920, 3)
# 0
# {50: 'Red', 71: 'Brown'}
# red 61.0
# orange 223.5
# orange 223.0
# orange 179.0
# [47, 50, 68, 71]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 87.5
# orange 213.0
# orange 232.5
# orange 202.0
# [49, 71]
# reached if
# (1080, 1920, 3)
# 0
# {49: 'Red', 71: 'Brown'}
# orange 213.0
# orange 179.0
# orange 196.5
# [18, 49, 71]
# Colors:  Brown Red  *  Brown
# (1080, 1920, 3)
# 120
# {}
# red 55.0
# orange 211.5
# orange 143.5
# orange 208.0
# [50, 71]
# reached if
# (1080, 1920, 3)
# 0
# {50: 'Red', 71: 'Brown'}
# red 71.5
# orange 210.0
# orange 219.5
# orange 198.5
# [50, 52, 71, 73]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 61.5
# orange 207.5
# orange 222.5
# orange 170.5
# [53, 75]
# reached if
# (1080, 1920, 3)
# 0
# {53: 'Red', 75: 'Brown'}
# green 52.5
# red 61.0
# orange 181.0
# orange 60.5
# orange 72.0
# orange 189.5
# [29, 53, 55, 56, 75, 77]
# Colors:  Brown Red  *  Green
# (1080, 1920, 3)
# 1200000
# {}
# red 53.0
# orange 194.0
# orange 232.0
# orange 184.0
# [29, 61, 82]
# Colors:  Brown Red  *  Brown
# (1080, 1920, 3)
# 120
# {}
# orange 219.0
# orange 185.5
# orange 177.5
# [30, 84]
# reached if
# (1080, 1920, 3)
# 0
# {84: 'Brown', 30: 'Brown'}
# orange 157.5
# orange 95.0
# orange 159.0
# [30, 84, 85]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 133.0
# orange 113.0
# orange 101.0
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# orange 50.5
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# [91]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown'}
# brown 83.0
# [91, 167]
# reached if
# (1080, 1920, 3)
# 0
# {91: 'Brown', 167: 'Brown'}
# red 110.5
# red 86.5
# red 64.0
# orange 177.5
# orange 147.5
# orange 100.0
# brown 66.0
# brown 62.5
# [91, 125, 127, 151, 152, 167, 173, 176]
# Colors:  Brown Red  *  Brown
# (1080, 1920, 3)
# 120
# {}
# brown 51.0
# brown 92.0
# [98, 127]
# reached if
# (1080, 1920, 3)
# 0
# {127: 'Brown', 98: 'Brown'}
# brown 77.0
# [86, 98, 127]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# brown 65.5
# [95]
# reached if
# (1080, 1920, 3)
# 0
# {95: 'Brown'}
# red 67.0
# red 63.0
# red 53.0
# orange 90.5
# brown 69.5
# brown 102.5
# [95, 98, 101, 120, 127, 147, 149, 172]
# Colors:  Brown Brown  *  Red
# (1080, 1920, 3)
# 1100
# {}
# green 59.5
# red 67.0
# red 105.5
# red 82.0
# orange 95.0
# orange 156.5
# orange 74.5
# [101, 125, 126, 145, 149]
# Colors:  Red Green  *  Red
# (1080, 1920, 3)
# 2500
# {}
# red 85.5
# red 66.0
# orange 129.5
# orange 171.5
# orange 133.0
# [91, 117, 137]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 84.5
# red 51.0
# orange 181.0
# orange 213.5
# orange 143.5
# [82, 108, 128]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 68.5
# red 55.5
# orange 102.5
# orange 156.5
# orange 161.5
# [65, 91, 111]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 89.0
# red 61.0
# orange 203.5
# orange 124.0
# orange 129.0
# [61, 87, 108]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 77.5
# orange 175.5
# orange 142.0
# orange 82.5
# [90, 112]
# reached if
# (1080, 1920, 3)
# 0
# {90: 'Red', 112: 'Brown'}
# red 52.0
# red 54.0
# orange 184.0
# orange 74.5
# orange 92.0
# [65, 90, 91, 111, 112]
# Colors:  Red Red  *  Red
# (1080, 1920, 3)
# 2200
# {}
# orange 116.0
# orange 70.0
# [111]
# reached if
# (1080, 1920, 3)
# 0
# {111: 'Brown'}
# orange 67.5
# [111, 112]
# reached if
# (1080, 1920, 3)
# 0
# {111: 'Brown', 112: 'Brown'}
# orange 53.0
# [111, 112]
# reached if
# (1080, 1920, 3)
# 0
# {111: 'Brown', 112: 'Brown'}
# orange 87.5
# [111, 112, 113]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# orange 103.5
# orange 51.0
# [115]
# reached if
# (1080, 1920, 3)
# 0
# {115: 'Brown'}
# red 65.0
# red 87.0
# orange 161.0
# orange 190.5
# orange 129.0
# [93, 113, 115, 118]
# Colors:  Red Brown  *  Brown
# (1080, 1920, 3)
# 210
# {}
# orange 145.0
# orange 59.0
# brown 52.5
# [92, 119]
# reached if
# (1080, 1920, 3)
# 0
# {92: 'Brown', 119: 'Brown'}
# green 100.0
# red 62.5
# orange 137.5
# orange 75.0
# [92, 97, 99, 119, 120]
# Colors:  Brown Green  *  Red
# (1080, 1920, 3)
# 1500
# {}
# orange 86.5
# [119]
# reached if
# (1080, 1920, 3)
# 0
# {119: 'Brown'}
# green 52.5
# orange 108.5
# [102, 119, 124]
# Colors:  Green Brown  *  Brown
# (1080, 1920, 3)
# 510
# {}
# green 71.0
# orange 143.0
# orange 101.5
# [93, 97, 120]
# Colors:  Green Yellow  *  Brown
# (1080, 1920, 3)
# 540
# {}
# green 97.5
# red 58.5
# orange 137.0
# orange 96.5
# [98, 99, 120]
# Colors:  Green Red  *  Brown
# (1080, 1920, 3)
# 520
# {}
# green 54.5
# orange 152.5
# orange 68.0
# orange 106.5
# [100, 120]
# reached if
# (1080, 1920, 3)
# 0
# {100: 'Green', 120: 'Brown'}
# red 69.5
# orange 124.0
# orange 109.5
# orange 84.5
# [100, 102, 120, 122]
# Colors:  Green Red  *  Brown
# (1080, 1920, 3)
# 520
# {}
# orange 140.0
# orange 105.5
# orange 84.0
# brown 52.5
# [96, 124]
# reached if
# (1080, 1920, 3)
# 0
# {96: 'Brown', 124: 'Brown'}
# orange 130.5
# orange 53.0
# [96, 124, 125]
# Colors:  Brown Brown  *  Brown
# (1080, 1920, 3)
# 110
# {}
# red 59.0
# red 76.5
# orange 199.5
# orange 128.0
# orange 158.0
# [81, 107, 127]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 106.0
# red 61.5
# orange 188.0
# orange 142.0
# orange 144.0
# black 51.0
# [1, 79, 104, 124]
# Colors:  Black Red  *  Red
# (1080, 1920, 3)
# 200
# {}
# red 88.5
# red 59.5
# orange 191.5
# orange 124.5
# orange 130.0
# [78, 103, 124]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 105.5
# red 60.0
# orange 167.0
# orange 164.5
# orange 131.5
# [75, 100, 121]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 86.5
# orange 182.0
# orange 187.5
# orange 138.0
# [100, 121]
# reached if
# (1080, 1920, 3)
# 0
# {100: 'Red', 121: 'Brown'}
# green 68.5
# red 57.5
# orange 175.5
# orange 90.0
# orange 60.5
# [74, 100, 121]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 90.0
# orange 201.5
# orange 201.5
# orange 116.5
# [95, 115]
# reached if
# (1080, 1920, 3)
# 0
# {95: 'Red', 115: 'Brown'}
# green 56.0
# red 88.0
# red 56.0
# orange 167.5
# orange 119.5
# orange 136.5
# [67, 92, 95, 113, 115]
# Colors:  Red Green  *  Red
# (1080, 1920, 3)
# 2500
# {}
# red 90.5
# red 69.5
# orange 172.5
# orange 208.0
# orange 139.0
# [67, 93, 113]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# green 73.0
# red 77.0
# red 61.0
# orange 174.5
# orange 62.5
# orange 146.5
# [68, 92, 93, 113]
# Colors:  Red Green  *  Red
# (1080, 1920, 3)
# 2500
# {}
# red 101.5
# orange 179.0
# orange 147.5
# orange 157.0
# [94, 114]
# reached if
# (1080, 1920, 3)
# 0
# {94: 'Red', 114: 'Brown'}
# red 80.5
# orange 176.5
# orange 116.5
# orange 128.0
# [94, 97, 114, 118]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 80.5
# red 62.5
# orange 167.5
# orange 103.5
# orange 107.0
# [72, 98, 119]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 83.0
# red 67.0
# orange 162.0
# orange 186.5
# orange 147.0
# black 51.0
# [1, 74, 100, 122]
# Colors:  Black Red  *  Red
# (1080, 1920, 3)
# 200
# {}
# green 122.0
# red 54.5
# orange 170.5
# orange 111.5
# [97, 99, 121]
# Colors:  Green Red  *  Brown
# (1080, 1920, 3)
# 520
# {}
# orange 88.0
# [126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown'}
# [126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown'}
# [126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown'}
# [126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown'}
# [126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown'}
# [126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown'}
# [126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown'}
# [126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown'}
# orange 63.0
# [3, 126]
# reached if
# (1080, 1920, 3)
# 0
# {126: 'Brown', 3: 'Brown'}
# red 54.5
# red 57.0
# orange 59.5
# orange 79.0
# [1, 3, 15, 17, 126]
# Colors:  Red Brown  *  Brown
# (1080, 1920, 3)
# 210
# {}
# red 53.5
# orange 124.5
# orange 133.5
# [9, 25]
# reached if
# (1080, 1920, 3)
# 0
# {9: 'Red', 25: 'Brown'}
# orange 54.5
# [9, 25]
# reached if
# (1080, 1920, 3)
# 0
# {9: 'Red', 25: 'Brown'}
# [9, 25]
# reached if
# (1080, 1920, 3)
# 0
# {9: 'Red', 25: 'Brown'}
# [9, 25]
# reached if
# (1080, 1920, 3)
# 0
# {9: 'Red', 25: 'Brown'}
# [9, 25]
# reached if
# (1080, 1920, 3)
# 0
# {9: 'Red', 25: 'Brown'}
# [9, 25]
# reached if
# (1080, 1920, 3)
# 0
# {9: 'Red', 25: 'Brown'}
# [9, 25]
# reached if
# (1080, 1920, 3)
# 0
# {9: 'Red', 25: 'Brown'}
# orange 101.0
# [9, 25, 74]
# Colors:  Red Brown  *  Brown
# (1080, 1920, 3)
# 210
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# green 57.0
# orange 81.0
# [53, 71]
# reached if
# (1080, 1920, 3)
# 0
# {53: 'Green', 71: 'Brown'}
# red 56.0
# orange 139.5
# orange 68.5
# [53, 55, 71, 74]
# Colors:  Green Red  *  Brown
# (1080, 1920, 3)
# 520
# {}
# green 56.5
# red 81.0
# red 75.5
# orange 108.0
# orange 70.5
# [37, 58, 76]
# Colors:  Red Green  *  Brown
# (1080, 1920, 3)
# 250
# {}
# red 83.5
# red 59.5
# orange 54.5
# orange 115.5
# orange 82.0
# [31, 52, 70]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 80.5
# red 77.5
# orange 109.0
# orange 144.0
# orange 82.5
# [24, 45, 64]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 80.5
# red 78.0
# orange 115.0
# orange 130.0
# orange 100.0
# [30, 51, 69]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 82.0
# red 71.0
# orange 118.5
# orange 152.5
# orange 79.0
# black 56.5
# [30, 51, 70, 155]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 92.5
# red 70.5
# orange 105.0
# orange 57.5
# orange 83.5
# [31, 52, 70]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 79.5
# red 58.0
# orange 100.5
# orange 84.5
# orange 101.0
# [30, 51, 68]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 80.5
# red 74.5
# orange 123.0
# orange 129.5
# [29, 51, 69]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 101.0
# red 74.5
# orange 135.5
# orange 113.0
# [28, 50, 67]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 54.0
# red 79.0
# orange 87.5
# orange 94.0
# [30, 52, 71]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 95.0
# red 89.5
# orange 126.0
# orange 114.5
# [37, 58, 76]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# green 68.5
# red 82.5
# red 83.5
# orange 136.0
# orange 66.0
# [41, 62, 63, 81]
# Colors:  Red Red  *  Green
# (1080, 1920, 3)
# 2200000
# {}
# red 85.0
# red 79.0
# orange 125.0
# orange 121.5
# orange 77.0
# [50, 71, 89]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 74.5
# red 74.0
# orange 64.0
# orange 108.0
# [60, 81, 99]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 79.5
# red 75.5
# orange 94.5
# orange 61.0
# orange 67.0
# [67, 88, 107]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 72.0
# red 70.0
# orange 84.5
# orange 52.5
# [75, 96, 115]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# red 73.0
# red 82.0
# orange 113.0
# orange 113.0
# orange 69.0
# black 69.5
# [1, 82, 103, 122]
# Colors:  Black Red  *  Red
# (1080, 1920, 3)
# 200
# {}
# green 66.5
# red 73.0
# orange 114.0
# orange 82.5
# black 72.0
# [1, 82, 102, 121]
# Colors:  Black Red  *  Green
# (1080, 1920, 3)
# 200000
# {}
# green 52.0
# red 66.5
# red 78.0
# orange 100.5
# orange 70.0
# black 53.0
# [1, 78, 100, 118]
# Colors:  Black Red  *  Green
# (1080, 1920, 3)
# 200000
# {}
# red 69.5
# red 71.5
# orange 102.5
# orange 64.5
# black 55.0
# [1, 74, 96, 114]
# Colors:  Black Red  *  Red
# (1080, 1920, 3)
# 200
# {}
# red 62.5
# red 69.0
# orange 50.5
# orange 90.0
# orange 88.0
# [69, 91, 108]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# green 61.0
# red 88.5
# red 73.0
# orange 109.5
# orange 80.5
# [64, 86, 104]
# Colors:  Red Green  *  Brown
# (1080, 1920, 3)
# 250
# {}
# red 80.5
# red 78.0
# orange 120.0
# orange 144.0
# orange 74.5
# [58, 79, 97]
# Colors:  Red Red  *  Brown
# (1080, 1920, 3)
# 220
# {}
# green 68.0
# red 70.5
# red 78.0
# orange 127.0
# orange 100.5
# [50, 71, 90]
# Colors:  Red Green  *  Brown
# (1080, 1920, 3)
# 250
# {}
# green 57.5
# red 85.0
# red 67.0
# orange 109.5
# orange 67.0
# [50, 72, 90]
# Colors:  Red Green  *  Brown
# (1080, 1920, 3)
# 250
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# []
# reached if
# (1080, 1920, 3)
# 0
# {}
# black 3564.0
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# black 3564.0
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# black 3564.0
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
# [1]
# reached if
# (1080, 1920, 3)
# 0
# {1: 'Black'}
